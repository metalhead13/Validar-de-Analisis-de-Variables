# %%
import pandas as pd
import numpy as np
pd.set_option('display.precision', 4)
pd.set_option('display.float_format',  '{:24}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

# %%
def corregirColumna(df, col):
    df1 = df[col].astype(str).copy()
    df1 = df1.apply(lambda x: list(x.split(".",1))[0])
    return df1

# %%
file = 'C:/Users/N1567011/OneDrive - Liberty Mutual/Documents/Proyectos/Chile/Khalil Kawssan/Comparacion/base_ambas_companias_aseg.csv'
dfs = pd.read_csv(file, sep = ';', 
                  encoding='ISO-8859-1',
                  low_memory=False, 
                  error_bad_lines=False, warn_bad_lines=False, nrows=500000, dtype=str)
dfs.columns = dfs.columns.str.upper()
dfs
# Out:
#           SSEGURO   CAGENTE CAGRSEG    POLIZA ITEM     INI_VIG FIN_VIG_ORIG  \
# 0         2618871  00995032     NaN   6287875    1  27/02/2013   27/02/2014
# 1         3591452  07965010     NaN   6383242    3  05/04/2014   05/04/2015
# 2         3476389  07685025    3204   6372976    1  29/01/2014   29/01/2015
# 3         9967651  09947380    4284   6894832   92  02/01/2019   16/08/2019
# 4         9751333  08954010     NaN   6953759    1  15/11/2018   15/11/2019
# ...           ...       ...     ...       ...  ...         ...          ...
# 499995    2280259  07600010     NaN   6258485    1  08/09/2012   08/09/2013
# 499996    1585764  07600010     NaN   6181073    1  08/09/2011   08/09/2012
# 499997  900194642  07130024    5397  61007845    1  15/12/2017   15/12/2019
# 499998  903676330  07130024    4447  61136831    1  15/12/2019   15/12/2020
# 499999  905498433  07130024    4447  61313038    1  15/12/2020   15/12/2021
#
# ...

# %%
dfs['MOTIVO_CANCEL_ANUL'].value_counts()
# Out:
# Series([], Name: MOTIVO_CANCEL_ANUL, dtype: int64)

# %%
dfs.loc[dfs['ORIGEN']=='LIBER','ORIGEN'] = 'LIBERTY'
dfs['KEY'] = dfs['POLIZA'].astype(str) + '-' + dfs['ITEM'].astype(str) + '-' + dfs['ORIGEN'].astype(str)

# %%
dfs['FECHA_NACIMIENTO'] = pd.to_datetime(dfs['FECHA_NACIMIENTO'], format='%d/%m/%Y', errors = 'coerce').dt.strftime('%Y-%m-%d')

# %%
dfs['FIN_VIG_ORIG'] = pd.to_datetime(dfs['FIN_VIG_ORIG'], format='%d/%m/%Y', errors = 'coerce').dt.strftime('%Y-%m-%d')
dfs['INI_VIG'] = pd.to_datetime(dfs['INI_VIG'], format='%d/%m/%Y', errors = 'coerce').dt.strftime('%Y-%m-%d')
dfs['FIN_VIG_ACT'] = pd.to_datetime(dfs['FIN_VIG_ACT'], format='%d/%m/%Y', errors = 'coerce').dt.strftime('%Y-%m-%d')
dfs['DATE_UPDATE'] = pd.to_datetime(dfs['DATE_UPDATE'], format='%d/%m/%Y', errors = 'coerce').dt.strftime('%Y-%m-%d')
dfs['FECHA_COTRENOV'] = pd.to_datetime(dfs['FECHA_COTRENOV'],format="%d%b%Y:%H:%M:%S", errors = 'coerce').dt.strftime('%Y-%m-%d')

# %%
dfs.isna().sum()
# Out:
# SSEGURO             195647
# CAGENTE             195647
# CAGRSEG             342403
# POLIZA                   0
# ITEM                     0
#                      ...
# NACIONALIDAD         57387
# SEXO_ASEGURADO       34609
# FECHA_NACIMIENTO     31521
# EDAD_ASEGURADO       31521
# KEY                      0
# Length: 92, dtype: int64

# %%
#dfs.info(verbose=True)

# %%
file = 'C:/Users/N1567011/OneDrive - Liberty Mutual/Documents/Proyectos/Chile/Khalil Kawssan/Comparacion/APTP_BASE_AMBAS_COMPANIAS_ASEG.csv'
dfp = pd.read_csv(file, sep=';',encoding='utf-8-sig', low_memory=False, dtype=str, 
                 error_bad_lines=False, 
                 warn_bad_lines=False,
                  nrows=500000,
                lineterminator='\n')

# %%
dfp['KEY'] = dfp['POLIZA'].astype(str) + '-' + dfp['ITEM'].astype(str) + '-' + dfp['ORIGEN'].astype(str)
dfp.head()
# Out:
#   SSEGURO   CAGENTE CAGRSEG   POLIZA ITEM     INI_VIG FIN_VIG_ORIG  \
# 0  481133  00054010    1852  6006870  100  2010-01-22   2010-10-23
# 1  494715  00054010    1852  6006870  101  2010-01-30   2010-10-23
# 2  522349  00054010    1852  6006870  102  2010-02-05   2010-10-23
# 3  543518  00054010    1852  6006870  103  2010-02-23   2010-10-23
# 4  555526  00054010    1852  6006870  104  2010-03-10   2010-10-23
#
#   FIN_VIG_ACT DIAS_VIGENTE DIAS_SUSCRITOS VEH_CMARCA VEH_CMODELO VEH_CLASE  \
# 0  2010-10-23          274            274         23         408         L
# 1  2010-10-23          266            266         77         415         L
# 2  2010-10-23          260            260         25         218         L
# 3  2010-10-23          242            242         61         104         L
# 4  2010-10-23          227            227         61         161         L
#
#   VEH_CVERSION                       TVERSION         USO VEH_ANO PATENTE  \
# ...

# %%
#Ajuste de datos para comparar

dfp['FLOTA1']=corregirColumna(dfp,'FLOTA1')
dfs['FECHA_COTRENOV'] = pd.to_datetime(dfs['FECHA_COTRENOV'],format="%Y-%m-%d %H:%M:%S", errors = 'coerce').dt.strftime('%Y-%m-%d')

# %%
dfp.columns = dfp.columns.str.upper()
#dfp = dfp[['KEY','SSEGURO','LC_MODEL','LC_MODEL_DEF','MES_REF_INI','PRIMA_RECIBO','PRIMA_RECIBO_FINAL','COB_INI','COB_FIN','FECHA_COTRENOV','PLAN_DESC','TIPO_PLAN','ANTERIOR','NUM_ITEMS','COD_MARCA_P','COD_MODELO_P','COD_TIPO_P','CANAL','DURACION_PLAN','ORIGEN_MARCA','ANTIG_VEHICULO','PT_RO','DATE_UPDATE','FORMA_PAGO_INI','FORMA_PAGO_FIN','METODO_PAGO','RAZON_CUOTAS','TUVO_PT','FORMA_PAGO_DEF']]

# %%
dfp.isna().sum()
# Out:
# SSEGURO                  0
# CAGENTE                  0
# CAGRSEG             239209
# POLIZA                   0
# ITEM                     0
#                      ...
# NACIONALIDAD        336839
# SEXO_ASEGURADO      188373
# FECHA_NACIMIENTO    110834
# EDAD_ASEGURADO      110836
# KEY                      0
# Length: 90, dtype: int64

# %%
dfp[dfp.duplicated(['KEY'])]
# Out:
# Empty DataFrame
# ...

# %%
dfp[dfp.duplicated()].sort_values('KEY')
# Out:
# Empty DataFrame
# ...

# %%
dfp['KEY']= dfp['KEY'].astype(str)
dfs['KEY']= dfs['KEY'].astype(str)
df2 = pd.merge(dfs['KEY'], dfp['KEY'], how='outer',
      left_on=['KEY'],
      right_on=['KEY'],
      left_index=False,
      right_index=False, 
      sort=True,
     suffixes=('_x', '_y'), copy=True, indicator=True,
     validate=None)
df2
# Out:
#                        KEY     _merge
# 0       10361804-265-PENTA  left_only
# 1       10392980-713-PENTA  left_only
# 2       10392980-716-PENTA  left_only
# 3       10392980-747-PENTA  left_only
# 4       10392980-750-PENTA  left_only
# ...                    ...        ...
# 932784   6999743-1-LIBERTY  left_only
# 932785   6999748-1-LIBERTY  left_only
# 932786   6999888-1-LIBERTY  left_only
# 932787   6999890-1-LIBERTY  left_only
# 932788   6999892-1-LIBERTY  left_only
#
# [932789 rows x 2 columns]

# %%
df2.groupby(['_merge']).size()
# Out:
# _merge
# left_only     432789
# right_only    432789
# both           67211
# dtype: int64

# %%
dfp = dfp[dfp['KEY'].isin(dfs['KEY'])].dropna(how = 'all')
dfs = dfs[dfs['KEY'].isin(dfp['KEY'])].dropna(how = 'all')
dfp.shape
# Out:
# (67211, 90)

# %%
### SSEGURO

dfp1 = dfp[['KEY', 'SSEGURO']]
dfs1 = dfs[['KEY', 'SSEGURO']]

dfp1['SSEGURO'] = dfp1['SSEGURO'].astype(str).copy()
dfs1['SSEGURO'] = dfs1['SSEGURO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SSEGURO_p != dfm.SSEGURO_s) & (~dfm.SSEGURO_s.isnull()) & (~dfm.SSEGURO_p.isnull())].copy()
dfm1[['KEY','SSEGURO_p','SSEGURO_s']]
# Out:
# <ipython-input-24-46dfc34951e2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['SSEGURO'] = dfp1['SSEGURO'].astype(str).copy()
# <ipython-input-24-46dfc34951e2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['SSEGURO'] = dfs1['SSEGURO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO_p, SSEGURO_s]
# Index: []

# %%
### CAGENTE

dfp1 = dfp[['KEY', 'SSEGURO', 'CAGENTE']]
dfs1 = dfs[['KEY', 'CAGENTE']]

dfp1['CAGENTE'] = dfp1['CAGENTE'].astype(str).copy()
dfs1['CAGENTE'] = dfs1['CAGENTE'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CAGENTE_p != dfm.CAGENTE_s) & (~dfm.CAGENTE_s.isnull()) & (~dfm.CAGENTE_p.isnull())].copy()
dfm1[['KEY','SSEGURO','CAGENTE_p','CAGENTE_s']]
# Out:
# <ipython-input-25-809a89dd655a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['CAGENTE'] = dfp1['CAGENTE'].astype(str).copy()
# <ipython-input-25-809a89dd655a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['CAGENTE'] = dfs1['CAGENTE'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, CAGENTE_p, CAGENTE_s]
# Index: []

# %%
### CAGRSEG

dfp1 = dfp[['KEY', 'SSEGURO', 'CAGRSEG']]
dfs1 = dfs[['KEY', 'CAGRSEG']]

dfp1['CAGRSEG'] = dfp1['CAGRSEG'].astype(str).copy()
dfs1['CAGRSEG'] = dfs1['CAGRSEG'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CAGRSEG_p != dfm.CAGRSEG_s) & (~dfm.CAGRSEG_s.isnull()) & (~dfm.CAGRSEG_p.isnull())].copy()
dfm1[['KEY','SSEGURO','CAGRSEG_p','CAGRSEG_s']]
# Out:
# <ipython-input-26-8c159844712e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['CAGRSEG'] = dfp1['CAGRSEG'].astype(str).copy()
# <ipython-input-26-8c159844712e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['CAGRSEG'] = dfs1['CAGRSEG'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, CAGRSEG_p, CAGRSEG_s]
# Index: []

# %%
### POLIZA

dfp1 = dfp[['KEY', 'SSEGURO', 'POLIZA']]
dfs1 = dfs[['KEY', 'POLIZA']]

dfp1['POLIZA'] = dfp1['POLIZA'].astype(str).copy()
dfs1['POLIZA'] = dfs1['POLIZA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.POLIZA_p != dfm.POLIZA_s) & (~dfm.POLIZA_s.isnull()) & (~dfm.POLIZA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','POLIZA_p','POLIZA_s']]
# Out:
# <ipython-input-27-11a411c8fd25>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['POLIZA'] = dfp1['POLIZA'].astype(str).copy()
# <ipython-input-27-11a411c8fd25>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['POLIZA'] = dfs1['POLIZA'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, POLIZA_p, POLIZA_s]
# Index: []

# %%
### ITEM

dfp1 = dfp[['KEY', 'SSEGURO', 'ITEM']]
dfs1 = dfs[['KEY', 'ITEM']]

dfp1['ITEM'] = dfp1['ITEM'].astype(str).copy()
dfs1['ITEM'] = dfs1['ITEM'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ITEM_p != dfm.ITEM_s) & (~dfm.ITEM_s.isnull()) & (~dfm.ITEM_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ITEM_p','ITEM_s']]
# Out:
# <ipython-input-28-5bbd65a4a562>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ITEM'] = dfp1['ITEM'].astype(str).copy()
# <ipython-input-28-5bbd65a4a562>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ITEM'] = dfs1['ITEM'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, ITEM_p, ITEM_s]
# Index: []

# %%
### INI_VIG

dfp1 = dfp[['KEY', 'SSEGURO', 'INI_VIG']]
dfs1 = dfs[['KEY', 'INI_VIG']]

dfp1['INI_VIG'] = dfp1['INI_VIG'].astype(str).copy()
dfs1['INI_VIG'] = dfs1['INI_VIG'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.INI_VIG_p != dfm.INI_VIG_s) & (~dfm.INI_VIG_s.isnull()) & (~dfm.INI_VIG_p.isnull())].copy()
dfm1[['KEY','SSEGURO','INI_VIG_p','INI_VIG_s']]
# Out:
# <ipython-input-29-5a22819c5b66>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['INI_VIG'] = dfp1['INI_VIG'].astype(str).copy()
# <ipython-input-29-5a22819c5b66>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['INI_VIG'] = dfs1['INI_VIG'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, INI_VIG_p, INI_VIG_s]
# Index: []

# %%
### FIN_VIG_ORIG

dfp1 = dfp[['KEY', 'SSEGURO', 'FIN_VIG_ORIG']]
dfs1 = dfs[['KEY', 'FIN_VIG_ORIG']]

dfp1['FIN_VIG_ORIG'] = dfp1['FIN_VIG_ORIG'].astype(str).copy()
dfs1['FIN_VIG_ORIG'] = dfs1['FIN_VIG_ORIG'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FIN_VIG_ORIG_p != dfm.FIN_VIG_ORIG_s) & (~dfm.FIN_VIG_ORIG_s.isnull()) & (~dfm.FIN_VIG_ORIG_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FIN_VIG_ORIG_p','FIN_VIG_ORIG_s']]
# Out:
# <ipython-input-30-72f930830807>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FIN_VIG_ORIG'] = dfp1['FIN_VIG_ORIG'].astype(str).copy()
# <ipython-input-30-72f930830807>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FIN_VIG_ORIG'] = dfs1['FIN_VIG_ORIG'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FIN_VIG_ORIG_p, FIN_VIG_ORIG_s]
# Index: []

# %%
### FIN_VIG_ACT

dfp1 = dfp[['KEY', 'SSEGURO', 'FIN_VIG_ACT']]
dfs1 = dfs[['KEY', 'FIN_VIG_ACT']]

dfp1['FIN_VIG_ACT'] = dfp1['FIN_VIG_ACT'].astype(str).copy()
dfs1['FIN_VIG_ACT'] = dfs1['FIN_VIG_ACT'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FIN_VIG_ACT_p != dfm.FIN_VIG_ACT_s) & (~dfm.FIN_VIG_ACT_s.isnull()) & (~dfm.FIN_VIG_ACT_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FIN_VIG_ACT_p','FIN_VIG_ACT_s']]
# Out:
# <ipython-input-31-ac545ddd6b98>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FIN_VIG_ACT'] = dfp1['FIN_VIG_ACT'].astype(str).copy()
# <ipython-input-31-ac545ddd6b98>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FIN_VIG_ACT'] = dfs1['FIN_VIG_ACT'].astype(str).copy()
#                       KEY    SSEGURO FIN_VIG_ACT_p FIN_VIG_ACT_s
# 63462  61388119-1-LIBERTY  906118132    2022-06-06    2022-06-18
# 66679  61416374-1-LIBERTY  906358167    2022-08-31    2022-05-24

# %%
### DIAS_VIGENTE

dfp1 = dfp[['KEY', 'SSEGURO', 'DIAS_VIGENTE']]
dfs1 = dfs[['KEY', 'DIAS_VIGENTE']]

dfp1['DIAS_VIGENTE'] = dfp1['DIAS_VIGENTE'].astype(str).copy()
dfs1['DIAS_VIGENTE'] = dfs1['DIAS_VIGENTE'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DIAS_VIGENTE_p != dfm.DIAS_VIGENTE_s) & (~dfm.DIAS_VIGENTE_s.isnull()) & (~dfm.DIAS_VIGENTE_p.isnull())].copy()
dfm1[['KEY','SSEGURO','DIAS_VIGENTE_p','DIAS_VIGENTE_s']]
# Out:
# <ipython-input-32-d9dbf0fff63a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['DIAS_VIGENTE'] = dfp1['DIAS_VIGENTE'].astype(str).copy()
# <ipython-input-32-d9dbf0fff63a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['DIAS_VIGENTE'] = dfs1['DIAS_VIGENTE'].astype(str).copy()
#                       KEY    SSEGURO DIAS_VIGENTE_p DIAS_VIGENTE_s
# 63462  61388119-1-LIBERTY  906118132            353            365
# ...

# %%
### DIAS_SUSCRITOS

dfp1 = dfp[['KEY', 'SSEGURO', 'DIAS_SUSCRITOS']]
dfs1 = dfs[['KEY', 'DIAS_SUSCRITOS']]

dfp1['DIAS_SUSCRITOS'] = dfp1['DIAS_SUSCRITOS'].astype(str).copy()
dfs1['DIAS_SUSCRITOS'] = dfs1['DIAS_SUSCRITOS'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DIAS_SUSCRITOS_p != dfm.DIAS_SUSCRITOS_s) & (~dfm.DIAS_SUSCRITOS_s.isnull()) & (~dfm.DIAS_SUSCRITOS_p.isnull())].copy()
dfm1[['KEY','SSEGURO','DIAS_SUSCRITOS_p','DIAS_SUSCRITOS_s']]
# Out:
# <ipython-input-33-c0efacf7bf5e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['DIAS_SUSCRITOS'] = dfp1['DIAS_SUSCRITOS'].astype(str).copy()
# <ipython-input-33-c0efacf7bf5e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['DIAS_SUSCRITOS'] = dfs1['DIAS_SUSCRITOS'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, DIAS_SUSCRITOS_p, DIAS_SUSCRITOS_s]
# Index: []

# %%
### VEH_CMARCA

dfp1 = dfp[['KEY', 'SSEGURO', 'VEH_CMARCA']]
dfs1 = dfs[['KEY', 'VEH_CMARCA']]

dfp1['VEH_CMARCA'] = dfp1['VEH_CMARCA'].astype(str).copy()
dfs1['VEH_CMARCA'] = dfs1['VEH_CMARCA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CMARCA_p != dfm.VEH_CMARCA_s) & (~dfm.VEH_CMARCA_s.isnull()) & (~dfm.VEH_CMARCA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','VEH_CMARCA_p','VEH_CMARCA_s']]
# Out:
# <ipython-input-34-a9328fb4c082>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['VEH_CMARCA'] = dfp1['VEH_CMARCA'].astype(str).copy()
# <ipython-input-34-a9328fb4c082>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['VEH_CMARCA'] = dfs1['VEH_CMARCA'].astype(str).copy()
#                       KEY    SSEGURO VEH_CMARCA_p VEH_CMARCA_s
# 11465  61008920-2-LIBERTY  900006999         1262          1E3
# 13118  61022534-2-LIBERTY  900147490         1110          1E3
# ...

# %%
### VEH_CMODELO

dfp1 = dfp[['KEY', 'SSEGURO', 'VEH_CMODELO']]
dfs1 = dfs[['KEY', 'VEH_CMODELO']]

dfp1['VEH_CMODELO'] = dfp1['VEH_CMODELO'].astype(str).copy()
dfs1['VEH_CMODELO'] = dfs1['VEH_CMODELO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CMODELO_p != dfm.VEH_CMODELO_s) & (~dfm.VEH_CMODELO_s.isnull()) & (~dfm.VEH_CMODELO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','VEH_CMODELO_p','VEH_CMODELO_s']]
# Out:
# <ipython-input-35-ca0624451e53>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['VEH_CMODELO'] = dfp1['VEH_CMODELO'].astype(str).copy()
# <ipython-input-35-ca0624451e53>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['VEH_CMODELO'] = dfs1['VEH_CMODELO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, VEH_CMODELO_p, VEH_CMODELO_s]
# Index: []

# %%
### VEH_CLASE

dfp1 = dfp[['KEY', 'SSEGURO', 'VEH_CLASE']]
dfs1 = dfs[['KEY', 'VEH_CLASE']]

dfp1['VEH_CLASE'] = dfp1['VEH_CLASE'].astype(str).copy()
dfs1['VEH_CLASE'] = dfs1['VEH_CLASE'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CLASE_p != dfm.VEH_CLASE_s) & (~dfm.VEH_CLASE_s.isnull()) & (~dfm.VEH_CLASE_p.isnull())].copy()
dfm1[['KEY','SSEGURO','VEH_CLASE_p','VEH_CLASE_s']]
# Out:
# <ipython-input-36-5a2b38cc7790>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['VEH_CLASE'] = dfp1['VEH_CLASE'].astype(str).copy()
# <ipython-input-36-5a2b38cc7790>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['VEH_CLASE'] = dfs1['VEH_CLASE'].astype(str).copy()
#                       KEY    SSEGURO VEH_CLASE_p VEH_CLASE_s
# 236     6057038-2-LIBERTY     626179           L           P
# 1896    6065574-1-LIBERTY     402453           L           P
# ...

# %%
### VEH_CVERSION

dfp1 = dfp[['KEY', 'SSEGURO', 'VEH_CVERSION']]
dfs1 = dfs[['KEY', 'VEH_CVERSION']]

dfp1['VEH_CVERSION'] = dfp1['VEH_CVERSION'].astype(str).copy()
dfs1['VEH_CVERSION'] = dfs1['VEH_CVERSION'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CVERSION_p != dfm.VEH_CVERSION_s) & (~dfm.VEH_CVERSION_s.isnull()) & (~dfm.VEH_CVERSION_p.isnull())].copy()
dfm1[['KEY','SSEGURO','VEH_CVERSION_p','VEH_CVERSION_s']]
# Out:
# <ipython-input-37-3b53b86e76b8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['VEH_CVERSION'] = dfp1['VEH_CVERSION'].astype(str).copy()
# <ipython-input-37-3b53b86e76b8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['VEH_CVERSION'] = dfs1['VEH_CVERSION'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, VEH_CVERSION_p, VEH_CVERSION_s]
# Index: []

# %%
### TVERSION

dfp1 = dfp[['KEY', 'SSEGURO', 'TVERSION']]
dfs1 = dfs[['KEY', 'TVERSION']]

dfp1['TVERSION'] = dfp1['TVERSION'].astype(str).copy()
dfs1['TVERSION'] = dfs1['TVERSION'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TVERSION_p != dfm.TVERSION_s) & (~dfm.TVERSION_s.isnull()) & (~dfm.TVERSION_p.isnull())].copy()
dfm1[['KEY','SSEGURO','TVERSION_p','TVERSION_s']]
# Out:
# <ipython-input-38-eb83ecf50861>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['TVERSION'] = dfp1['TVERSION'].astype(str).copy()
# <ipython-input-38-eb83ecf50861>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['TVERSION'] = dfs1['TVERSION'].astype(str).copy()
#                       KEY    SSEGURO  \
# 3528    6076134-1-LIBERTY     540477
# 3615    6076522-1-LIBERTY     543654
# 3616    6076522-3-LIBERTY    1090601
# 4768    6081372-4-LIBERTY     581588
# ...

# %%
### USO

dfp1 = dfp[['KEY', 'SSEGURO', 'USO']]
dfs1 = dfs[['KEY', 'USO']]

dfp1['USO'] = dfp1['USO'].astype(str).copy()
dfs1['USO'] = dfs1['USO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.USO_p != dfm.USO_s) & (~dfm.USO_s.isnull()) & (~dfm.USO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','USO_p','USO_s']]
# Out:
# <ipython-input-39-9f0bce047997>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['USO'] = dfp1['USO'].astype(str).copy()
# <ipython-input-39-9f0bce047997>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['USO'] = dfs1['USO'].astype(str).copy()
#                       KEY    SSEGURO        USO_p       USO_s
# 3760    6077131-1-LIBERTY     549443  DESCONOCIDO  DESCONOCID
# 4533    6080356-1-LIBERTY     572219  DESCONOCIDO  DESCONOCID
# ...

# %%
### VEH_ANO

dfp1 = dfp[['KEY', 'SSEGURO', 'VEH_ANO']]
dfs1 = dfs[['KEY', 'VEH_ANO']]

dfp1['VEH_ANO'] = dfp1['VEH_ANO'].astype(str).copy()
dfs1['VEH_ANO'] = dfs1['VEH_ANO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_ANO_p != dfm.VEH_ANO_s) & (~dfm.VEH_ANO_s.isnull()) & (~dfm.VEH_ANO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','VEH_ANO_p','VEH_ANO_s']]
# Out:
# <ipython-input-40-f5fe6dc8a5c1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['VEH_ANO'] = dfp1['VEH_ANO'].astype(str).copy()
# <ipython-input-40-f5fe6dc8a5c1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['VEH_ANO'] = dfs1['VEH_ANO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, VEH_ANO_p, VEH_ANO_s]
# Index: []

# %%
### PATENTE

dfp1 = dfp[['KEY', 'SSEGURO', 'PATENTE']]
dfs1 = dfs[['KEY', 'PATENTE']]

dfp1['PATENTE'] = dfp1['PATENTE'].astype(str).copy()
dfs1['PATENTE'] = dfs1['PATENTE'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PATENTE_p != dfm.PATENTE_s) & (~dfm.PATENTE_s.isnull()) & (~dfm.PATENTE_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PATENTE_p','PATENTE_s']]
# Out:
# <ipython-input-41-70d790c0bae9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PATENTE'] = dfp1['PATENTE'].astype(str).copy()
# <ipython-input-41-70d790c0bae9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PATENTE'] = dfs1['PATENTE'].astype(str).copy()
#                       KEY    SSEGURO PATENTE_p PATENTE_s
# 64594  61399106-1-LIBERTY  906017298  "LKHZ74"  LKHZ74\r
# 64687  61399366-1-LIBERTY  906118346    LHZH27       nan

# %%
### VEH_CTIPO

dfp1 = dfp[['KEY', 'SSEGURO', 'VEH_CTIPO']]
dfs1 = dfs[['KEY', 'VEH_CTIPO']]

dfp1['VEH_CTIPO'] = dfp1['VEH_CTIPO'].astype(str).copy()
dfs1['VEH_CTIPO'] = dfs1['VEH_CTIPO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CTIPO_p != dfm.VEH_CTIPO_s) & (~dfm.VEH_CTIPO_s.isnull()) & (~dfm.VEH_CTIPO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','VEH_CTIPO_p','VEH_CTIPO_s']]
# Out:
# <ipython-input-42-6a43ff0ace53>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['VEH_CTIPO'] = dfp1['VEH_CTIPO'].astype(str).copy()
# <ipython-input-42-6a43ff0ace53>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['VEH_CTIPO'] = dfs1['VEH_CTIPO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, VEH_CTIPO_p, VEH_CTIPO_s]
# Index: []

# %%
### VEH_TIPO

dfp1 = dfp[['KEY', 'SSEGURO', 'VEH_TIPO']]
dfs1 = dfs[['KEY', 'VEH_TIPO']]

dfp1['VEH_TIPO'] = dfp1['VEH_TIPO'].astype(str).copy()
dfs1['VEH_TIPO'] = dfs1['VEH_TIPO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_TIPO_p != dfm.VEH_TIPO_s) & (~dfm.VEH_TIPO_s.isnull()) & (~dfm.VEH_TIPO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','VEH_TIPO_p','VEH_TIPO_s']]
# Out:
# <ipython-input-43-4d3ba1c83583>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['VEH_TIPO'] = dfp1['VEH_TIPO'].astype(str).copy()
# <ipython-input-43-4d3ba1c83583>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['VEH_TIPO'] = dfs1['VEH_TIPO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, VEH_TIPO_p, VEH_TIPO_s]
# Index: []

# %%
### TMARCA

dfp1 = dfp[['KEY', 'SSEGURO', 'TMARCA']]
dfs1 = dfs[['KEY', 'TMARCA']]

dfp1['TMARCA'] = dfp1['TMARCA'].astype(str).copy()
dfs1['TMARCA'] = dfs1['TMARCA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TMARCA_p != dfm.TMARCA_s) & (~dfm.TMARCA_s.isnull()) & (~dfm.TMARCA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','TMARCA_p','TMARCA_s']]
# Out:
# <ipython-input-44-d465f7523d68>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['TMARCA'] = dfp1['TMARCA'].astype(str).copy()
# <ipython-input-44-d465f7523d68>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['TMARCA'] = dfs1['TMARCA'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, TMARCA_p, TMARCA_s]
# Index: []

# %%
### TMODELO

dfp1 = dfp[['KEY', 'SSEGURO', 'TMODELO']]
dfs1 = dfs[['KEY', 'TMODELO']]

dfp1['TMODELO'] = dfp1['TMODELO'].astype(str).copy()
dfs1['TMODELO'] = dfs1['TMODELO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TMODELO_p != dfm.TMODELO_s) & (~dfm.TMODELO_s.isnull()) & (~dfm.TMODELO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','TMODELO_p','TMODELO_s']]
# Out:
# <ipython-input-45-31d61ddb03d6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['TMODELO'] = dfp1['TMODELO'].astype(str).copy()
# <ipython-input-45-31d61ddb03d6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['TMODELO'] = dfs1['TMODELO'].astype(str).copy()
#                       KEY    SSEGURO               TMODELO_p  \
# 2237    6069768-1-LIBERTY     457065       CARGO 1622 ó 1722
# 2633    6071834-1-LIBERTY     480557               FLB ó FLD
# ...

# %%
### NUM_MOTOR

dfp1 = dfp[['KEY', 'SSEGURO', 'NUM_MOTOR']]
dfs1 = dfs[['KEY', 'NUM_MOTOR']]

dfp1['NUM_MOTOR'] = dfp1['NUM_MOTOR'].astype(str).copy()
dfs1['NUM_MOTOR'] = dfs1['NUM_MOTOR'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NUM_MOTOR_p != dfm.NUM_MOTOR_s) & (~dfm.NUM_MOTOR_s.isnull()) & (~dfm.NUM_MOTOR_p.isnull())].copy()
dfm1[['KEY','SSEGURO','NUM_MOTOR_p','NUM_MOTOR_s']]
# Out:
# <ipython-input-46-e2bf11dc8e66>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['NUM_MOTOR'] = dfp1['NUM_MOTOR'].astype(str).copy()
# <ipython-input-46-e2bf11dc8e66>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['NUM_MOTOR'] = dfs1['NUM_MOTOR'].astype(str).copy()
#                       KEY    SSEGURO           NUM_MOTOR_p       NUM_MOTOR_s
# 12855  61020627-1-LIBERTY  900302907             9D192864           9D192864
# ...

# %%
### CORREDOR_RUT

dfp1 = dfp[['KEY', 'SSEGURO', 'CORREDOR_RUT']]
dfs1 = dfs[['KEY', 'CORREDOR_RUT']]

dfp1['CORREDOR_RUT'] = dfp1['CORREDOR_RUT'].astype(str).copy()
dfs1['CORREDOR_RUT'] = dfs1['CORREDOR_RUT'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CORREDOR_RUT_p != dfm.CORREDOR_RUT_s) & (~dfm.CORREDOR_RUT_s.isnull()) & (~dfm.CORREDOR_RUT_p.isnull())].copy()
dfm1[['KEY','SSEGURO','CORREDOR_RUT_p','CORREDOR_RUT_s']]
# Out:
# <ipython-input-47-e76bb14bb1f9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['CORREDOR_RUT'] = dfp1['CORREDOR_RUT'].astype(str).copy()
# <ipython-input-47-e76bb14bb1f9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['CORREDOR_RUT'] = dfs1['CORREDOR_RUT'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, CORREDOR_RUT_p, CORREDOR_RUT_s]
# Index: []

# %%
### CORREDOR

dfp1 = dfp[['KEY', 'SSEGURO', 'CORREDOR']]
dfs1 = dfs[['KEY', 'CORREDOR']]

dfp1['CORREDOR'] = dfp1['CORREDOR'].astype(str).copy()
dfs1['CORREDOR'] = dfs1['CORREDOR'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CORREDOR_p != dfm.CORREDOR_s) & (~dfm.CORREDOR_s.isnull()) & (~dfm.CORREDOR_p.isnull())].copy()
dfm1[['KEY','SSEGURO','CORREDOR_p','CORREDOR_s']]
# Out:
# <ipython-input-48-4740e9a018dc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['CORREDOR'] = dfp1['CORREDOR'].astype(str).copy()
# <ipython-input-48-4740e9a018dc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['CORREDOR'] = dfs1['CORREDOR'].astype(str).copy()
#                      KEY  SSEGURO  \
# 1      6013563-9-LIBERTY   489217
# 5      6020240-2-LIBERTY   522698
# 6      6021066-2-LIBERTY   571770
# 8      6021268-2-LIBERTY   552100
# 9      6021792-3-LIBERTY   481161
# ...

# %%
### COD_PRODUCTO

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_PRODUCTO']]
dfs1 = dfs[['KEY', 'COD_PRODUCTO']]

dfp1['COD_PRODUCTO'] = dfp1['COD_PRODUCTO'].astype(str).copy()
dfs1['COD_PRODUCTO'] = dfs1['COD_PRODUCTO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_PRODUCTO_p != dfm.COD_PRODUCTO_s) & (~dfm.COD_PRODUCTO_s.isnull()) & (~dfm.COD_PRODUCTO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_PRODUCTO_p','COD_PRODUCTO_s']]
# Out:
# <ipython-input-49-5d73d5250523>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_PRODUCTO'] = dfp1['COD_PRODUCTO'].astype(str).copy()
# <ipython-input-49-5d73d5250523>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_PRODUCTO'] = dfs1['COD_PRODUCTO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COD_PRODUCTO_p, COD_PRODUCTO_s]
# Index: []

# %%
### PRODUCTO

dfp1 = dfp[['KEY', 'SSEGURO', 'PRODUCTO']]
dfs1 = dfs[['KEY', 'PRODUCTO']]

dfp1['PRODUCTO'] = dfp1['PRODUCTO'].astype(str).copy()
dfs1['PRODUCTO'] = dfs1['PRODUCTO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRODUCTO_p != dfm.PRODUCTO_s) & (~dfm.PRODUCTO_s.isnull()) & (~dfm.PRODUCTO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PRODUCTO_p','PRODUCTO_s']]
# Out:
# <ipython-input-50-ce6ea0f000c9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PRODUCTO'] = dfp1['PRODUCTO'].astype(str).copy()
# <ipython-input-50-ce6ea0f000c9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PRODUCTO'] = dfs1['PRODUCTO'].astype(str).copy()
#                       KEY    SSEGURO            PRODUCTO_p  \
# 86      6039529-2-LIBERTY     586715     Vehículo Security
# 120     6045471-2-LIBERTY     713892     Vehículo Security
# ...

# %%
### COD_PLAN

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_PLAN']]
dfs1 = dfs[['KEY', 'COD_PLAN']]

dfp1['COD_PLAN'] = dfp1['COD_PLAN'].astype(str).copy()
dfs1['COD_PLAN'] = dfs1['COD_PLAN'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_PLAN_p != dfm.COD_PLAN_s) & (~dfm.COD_PLAN_s.isnull()) & (~dfm.COD_PLAN_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_PLAN_p','COD_PLAN_s']]
# Out:
# <ipython-input-51-c102445f3ba4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_PLAN'] = dfp1['COD_PLAN'].astype(str).copy()
# <ipython-input-51-c102445f3ba4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_PLAN'] = dfs1['COD_PLAN'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COD_PLAN_p, COD_PLAN_s]
# Index: []

# %%
### PLAN

dfp1 = dfp[['KEY', 'SSEGURO', 'PLAN']]
dfs1 = dfs[['KEY', 'PLAN']]

dfp1['PLAN'] = dfp1['PLAN'].astype(str).copy()
dfs1['PLAN'] = dfs1['PLAN'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PLAN_p != dfm.PLAN_s) & (~dfm.PLAN_s.isnull()) & (~dfm.PLAN_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PLAN_p','PLAN_s']]
# Out:
# <ipython-input-52-c448c99da47e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PLAN'] = dfp1['PLAN'].astype(str).copy()
# <ipython-input-52-c448c99da47e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PLAN'] = dfs1['PLAN'].astype(str).copy()
#                       KEY    SSEGURO                       PLAN_p  \
# 1846   6064855-30-LIBERTY     521977       CAMIÓN - TRACTO CAMIÓN
# 2002    6067479-1-LIBERTY     427855       CAMIÓN - TRACTO CAMIÓN
# ...

# %%
### DEDUCIBLE

dfp1 = dfp[['KEY', 'SSEGURO', 'DEDUCIBLE']]
dfs1 = dfs[['KEY', 'DEDUCIBLE']]

dfp1['DEDUCIBLE'] = dfp1['DEDUCIBLE'].astype(str).copy()
dfs1['DEDUCIBLE'] = dfs1['DEDUCIBLE'].astype(float).astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DEDUCIBLE_p != dfm.DEDUCIBLE_s) & (~dfm.DEDUCIBLE_s.isnull()) & (~dfm.DEDUCIBLE_p.isnull())].copy()
dfm1[['KEY','SSEGURO','DEDUCIBLE_p','DEDUCIBLE_s']]
# Out:
# <ipython-input-53-c73530feba58>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['DEDUCIBLE'] = dfp1['DEDUCIBLE'].astype(str).copy()
# <ipython-input-53-c73530feba58>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['DEDUCIBLE'] = dfs1['DEDUCIBLE'].astype(float).astype(str).copy()
#                       KEY    SSEGURO DEDUCIBLE_p DEDUCIBLE_s
# 67      6038204-4-LIBERTY     493667         0.0         5.0
# 196     6052574-2-LIBERTY     488202         3.0        10.0
# ...

# %%
### DEDUCIBLE_INI

dfp1 = dfp[['KEY', 'SSEGURO', 'DEDUCIBLE_INI']]
dfs1 = dfs[['KEY', 'DEDUCIBLE_INI']]

dfp1['DEDUCIBLE_INI'] = dfp1['DEDUCIBLE_INI'].astype(str).copy()
dfs1['DEDUCIBLE_INI'] = dfs1['DEDUCIBLE_INI'].astype(float).astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DEDUCIBLE_INI_p != dfm.DEDUCIBLE_INI_s) & (~dfm.DEDUCIBLE_INI_s.isnull()) & (~dfm.DEDUCIBLE_INI_p.isnull())].copy()
dfm1[['KEY','SSEGURO','DEDUCIBLE_INI_p','DEDUCIBLE_INI_s']]
# Out:
# <ipython-input-54-eb58386f697e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['DEDUCIBLE_INI'] = dfp1['DEDUCIBLE_INI'].astype(str).copy()
# <ipython-input-54-eb58386f697e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['DEDUCIBLE_INI'] = dfs1['DEDUCIBLE_INI'].astype(float).astype(str).copy()
#                        KEY    SSEGURO DEDUCIBLE_INI_p DEDUCIBLE_INI_s
# 2108     6068488-1-LIBERTY     447180             7.0             7.5
# ...

# %%
### CONTRATANTE_RUT

dfp1 = dfp[['KEY', 'SSEGURO', 'CONTRATANTE_RUT']]
dfs1 = dfs[['KEY', 'CONTRATANTE_RUT']]

dfp1['CONTRATANTE_RUT'] = dfp1['CONTRATANTE_RUT'].astype(str).copy()
dfs1['CONTRATANTE_RUT'] = dfs1['CONTRATANTE_RUT'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CONTRATANTE_RUT_p != dfm.CONTRATANTE_RUT_s) & (~dfm.CONTRATANTE_RUT_s.isnull()) & (~dfm.CONTRATANTE_RUT_p.isnull())].copy()
dfm1[['KEY','SSEGURO','CONTRATANTE_RUT_p','CONTRATANTE_RUT_s']]
# Out:
# <ipython-input-55-5b690d752553>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['CONTRATANTE_RUT'] = dfp1['CONTRATANTE_RUT'].astype(str).copy()
# <ipython-input-55-5b690d752553>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['CONTRATANTE_RUT'] = dfs1['CONTRATANTE_RUT'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, CONTRATANTE_RUT_p, CONTRATANTE_RUT_s]
# Index: []

# %%
### CONTRATANTE_NOMBRE

dfp1 = dfp[['KEY', 'SSEGURO', 'CONTRATANTE_NOMBRE']]
dfs1 = dfs[['KEY', 'CONTRATANTE_NOMBRE']]

dfp1['CONTRATANTE_NOMBRE'] = dfp1['CONTRATANTE_NOMBRE'].astype(str).copy()
dfs1['CONTRATANTE_NOMBRE'] = dfs1['CONTRATANTE_NOMBRE'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CONTRATANTE_NOMBRE_p != dfm.CONTRATANTE_NOMBRE_s) & (~dfm.CONTRATANTE_NOMBRE_s.isnull()) & (~dfm.CONTRATANTE_NOMBRE_p.isnull())].copy()
dfm1[['KEY','SSEGURO','CONTRATANTE_NOMBRE_p','CONTRATANTE_NOMBRE_s']]
# Out:
# <ipython-input-56-80420826be64>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['CONTRATANTE_NOMBRE'] = dfp1['CONTRATANTE_NOMBRE'].astype(str).copy()
# <ipython-input-56-80420826be64>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['CONTRATANTE_NOMBRE'] = dfs1['CONTRATANTE_NOMBRE'].astype(str).copy()
#                       KEY    SSEGURO  \
# 2      6014329-19-LIBERTY     789926
# 22     6027603-40-LIBERTY     583019
# 39     6031896-44-LIBERTY     641110
# ...

# %%
### FLOTA1

dfp1 = dfp[['KEY', 'SSEGURO', 'FLOTA1']]
dfs1 = dfs[['KEY', 'FLOTA1']]

dfp1['FLOTA1'] = dfp1['FLOTA1'].astype(str).copy()
dfs1['FLOTA1'] = dfs1['FLOTA1'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA1_p != dfm.FLOTA1_s) & (~dfm.FLOTA1_s.isnull()) & (~dfm.FLOTA1_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FLOTA1_p','FLOTA1_s']]
# Out:
# <ipython-input-57-a0fde33968d5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FLOTA1'] = dfp1['FLOTA1'].astype(str).copy()
# <ipython-input-57-a0fde33968d5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FLOTA1'] = dfs1['FLOTA1'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FLOTA1_p, FLOTA1_s]
# Index: []

# %%
### NRO_MASIVO

dfp1 = dfp[['KEY', 'SSEGURO', 'NRO_MASIVO']]
dfs1 = dfs[['KEY', 'NRO_MASIVO']]

dfp1['NRO_MASIVO'] = dfp1['NRO_MASIVO'].astype(str).copy()
dfs1['NRO_MASIVO'] = dfs1['NRO_MASIVO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NRO_MASIVO_p != dfm.NRO_MASIVO_s) & (~dfm.NRO_MASIVO_s.isnull()) & (~dfm.NRO_MASIVO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','NRO_MASIVO_p','NRO_MASIVO_s']]
# Out:
# <ipython-input-58-3c3c006bf25f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['NRO_MASIVO'] = dfp1['NRO_MASIVO'].astype(str).copy()
# <ipython-input-58-3c3c006bf25f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['NRO_MASIVO'] = dfs1['NRO_MASIVO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, NRO_MASIVO_p, NRO_MASIVO_s]
# Index: []

# %%
### PRIMA

dfp1 = dfp[['KEY', 'SSEGURO', 'PRIMA']]
dfs1 = dfs[['KEY', 'PRIMA']]

dfp1['PRIMA'] = dfp1['PRIMA'].astype(str).copy()
dfs1['PRIMA'] = dfs1['PRIMA'].astype(float).astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_p != dfm.PRIMA_s) & (~dfm.PRIMA_s.isnull()) & (~dfm.PRIMA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PRIMA_p','PRIMA_s']]
# Out:
# <ipython-input-59-bebf42a9ea5d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PRIMA'] = dfp1['PRIMA'].astype(str).copy()
# <ipython-input-59-bebf42a9ea5d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PRIMA'] = dfs1['PRIMA'].astype(float).astype(str).copy()
#                        KEY  SSEGURO        PRIMA_p       PRIMA_s
# 153    6049507-350-LIBERTY   571163   1.9777664761  1.9777664762
# 155    6049507-366-LIBERTY   827708   1.9777664761  1.9777664762
# ...

# %%
### PRIMA_TARIFA

dfp1 = dfp[['KEY', 'SSEGURO', 'PRIMA_TARIFA']]
dfs1 = dfs[['KEY', 'PRIMA_TARIFA']]

dfp1['PRIMA_TARIFA'] = dfp1['PRIMA_TARIFA'].astype(str).copy()
dfs1['PRIMA_TARIFA'] = dfs1['PRIMA_TARIFA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_TARIFA_p != dfm.PRIMA_TARIFA_s) & (~dfm.PRIMA_TARIFA_s.isnull()) & (~dfm.PRIMA_TARIFA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PRIMA_TARIFA_p','PRIMA_TARIFA_s']]
# Out:
# <ipython-input-60-9f3b977d4761>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PRIMA_TARIFA'] = dfp1['PRIMA_TARIFA'].astype(str).copy()
# <ipython-input-60-9f3b977d4761>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PRIMA_TARIFA'] = dfs1['PRIMA_TARIFA'].astype(str).copy()
#                        KEY    SSEGURO PRIMA_TARIFA_p PRIMA_TARIFA_s
# 1        6013563-9-LIBERTY     489217           23.0             23
# ...

# %%
### DESCUENTO

dfp1 = dfp[['KEY', 'SSEGURO', 'DESCUENTO']]
dfs1 = dfs[['KEY', 'DESCUENTO']]

dfp1['DESCUENTO'] = dfp1['DESCUENTO'].astype(str).copy()
dfs1['DESCUENTO'] = dfs1['DESCUENTO'].astype(float).astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DESCUENTO_p != dfm.DESCUENTO_s) & (~dfm.DESCUENTO_s.isnull()) & (~dfm.DESCUENTO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','DESCUENTO_p','DESCUENTO_s']]
# Out:
# <ipython-input-61-618017a888e1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['DESCUENTO'] = dfp1['DESCUENTO'].astype(str).copy()
# <ipython-input-61-618017a888e1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['DESCUENTO'] = dfs1['DESCUENTO'].astype(float).astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, DESCUENTO_p, DESCUENTO_s]
# Index: []

# %%
### COMISION

dfp1 = dfp[['KEY', 'SSEGURO', 'COMISION']]
dfs1 = dfs[['KEY', 'COMISION']]

dfp1['COMISION'] = dfp1['COMISION'].astype(str).copy()
dfs1['COMISION'] = dfs1['COMISION'].astype(float).astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COMISION_p != dfm.COMISION_s) & (~dfm.COMISION_s.isnull()) & (~dfm.COMISION_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COMISION_p','COMISION_s']]
# Out:
# <ipython-input-62-0323381b2499>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COMISION'] = dfp1['COMISION'].astype(str).copy()
# <ipython-input-62-0323381b2499>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COMISION'] = dfs1['COMISION'].astype(float).astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COMISION_p, COMISION_s]
# Index: []

# %%
### PRIMA_FINAL

dfp1 = dfp[['KEY', 'SSEGURO', 'PRIMA_FINAL']]
dfs1 = dfs[['KEY', 'PRIMA_FINAL']]

dfp1['PRIMA_FINAL'] = dfp1['PRIMA_FINAL'].astype(str).copy()
dfs1['PRIMA_FINAL'] = dfs1['PRIMA_FINAL'].astype(float).astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_FINAL_p != dfm.PRIMA_FINAL_s) & (~dfm.PRIMA_FINAL_s.isnull()) & (~dfm.PRIMA_FINAL_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PRIMA_FINAL_p','PRIMA_FINAL_s']]
# Out:
# <ipython-input-63-ddc52a9e7869>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PRIMA_FINAL'] = dfp1['PRIMA_FINAL'].astype(str).copy()
# <ipython-input-63-ddc52a9e7869>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PRIMA_FINAL'] = dfs1['PRIMA_FINAL'].astype(float).astype(str).copy()
#                        KEY  SSEGURO  PRIMA_FINAL_p PRIMA_FINAL_s
# 153    6049507-350-LIBERTY   571163   1.9777664761  1.9777664762
# ...

# %%
### COD_ENDOSO

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_ENDOSO']]
dfs1 = dfs[['KEY', 'COD_ENDOSO']]

dfp1['COD_ENDOSO'] = dfp1['COD_ENDOSO'].astype(str).copy()
dfs1['COD_ENDOSO'] = dfs1['COD_ENDOSO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_ENDOSO_p != dfm.COD_ENDOSO_s) & (~dfm.COD_ENDOSO_s.isnull()) & (~dfm.COD_ENDOSO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_ENDOSO_p','COD_ENDOSO_s']]
# Out:
# <ipython-input-64-b712b89b35d7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_ENDOSO'] = dfp1['COD_ENDOSO'].astype(str).copy()
# <ipython-input-64-b712b89b35d7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_ENDOSO'] = dfs1['COD_ENDOSO'].astype(str).copy()
#                       KEY    SSEGURO COD_ENDOSO_p COD_ENDOSO_s
# 63462  61388119-1-LIBERTY  906118132          375          100
# 64687  61399366-1-LIBERTY  906118346          803          100
# ...

# %%
### TDESCRIP

dfp1 = dfp[['KEY', 'SSEGURO', 'TDESCRIP']]
dfs1 = dfs[['KEY', 'TDESCRIP']]

dfp1['TDESCRIP'] = dfp1['TDESCRIP'].astype(str).copy()
dfs1['TDESCRIP'] = dfs1['TDESCRIP'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TDESCRIP_p != dfm.TDESCRIP_s) & (~dfm.TDESCRIP_s.isnull()) & (~dfm.TDESCRIP_p.isnull())].copy()
dfm1[['KEY','SSEGURO','TDESCRIP_p','TDESCRIP_s']]
# Out:
# <ipython-input-65-781ba4762390>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['TDESCRIP'] = dfp1['TDESCRIP'].astype(str).copy()
# <ipython-input-65-781ba4762390>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['TDESCRIP'] = dfs1['TDESCRIP'].astype(str).copy()
#                       KEY    SSEGURO  \
# 7       6021077-2-LIBERTY     581703
# 51      6034842-2-LIBERTY     566010
# 55      6035919-2-LIBERTY     481966
# 67      6038204-4-LIBERTY     493667
# ...

# %%
### ENDOSO_AGRUP

dfp1 = dfp[['KEY', 'SSEGURO', 'ENDOSO_AGRUP']]
dfs1 = dfs[['KEY', 'ENDOSO_AGRUP']]

dfp1['ENDOSO_AGRUP'] = dfp1['ENDOSO_AGRUP'].astype(str).copy()
dfs1['ENDOSO_AGRUP'] = dfs1['ENDOSO_AGRUP'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ENDOSO_AGRUP_p != dfm.ENDOSO_AGRUP_s) & (~dfm.ENDOSO_AGRUP_s.isnull()) & (~dfm.ENDOSO_AGRUP_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ENDOSO_AGRUP_p','ENDOSO_AGRUP_s']]
# Out:
# <ipython-input-66-7ef34a7dc040>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ENDOSO_AGRUP'] = dfp1['ENDOSO_AGRUP'].astype(str).copy()
# <ipython-input-66-7ef34a7dc040>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ENDOSO_AGRUP'] = dfs1['ENDOSO_AGRUP'].astype(str).copy()
#                       KEY    SSEGURO ENDOSO_AGRUP_p ENDOSO_AGRUP_s
# 63462  61388119-1-LIBERTY  906118132    CANCELACION     NUEVA PROD
# ...

# %%
### NOMBRE_CONVENIO

dfp1 = dfp[['KEY', 'SSEGURO', 'NOMBRE_CONVENIO']]
dfs1 = dfs[['KEY', 'NOMBRE_CONVENIO']]

dfp1['NOMBRE_CONVENIO'] = dfp1['NOMBRE_CONVENIO'].astype(str).copy()
dfs1['NOMBRE_CONVENIO'] = dfs1['NOMBRE_CONVENIO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NOMBRE_CONVENIO_p != dfm.NOMBRE_CONVENIO_s) & (~dfm.NOMBRE_CONVENIO_s.isnull()) & (~dfm.NOMBRE_CONVENIO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','NOMBRE_CONVENIO_p','NOMBRE_CONVENIO_s']]
# Out:
# <ipython-input-67-46bae265ead6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['NOMBRE_CONVENIO'] = dfp1['NOMBRE_CONVENIO'].astype(str).copy()
# <ipython-input-67-46bae265ead6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['NOMBRE_CONVENIO'] = dfs1['NOMBRE_CONVENIO'].astype(str).copy()
#                       KEY    SSEGURO                        NOMBRE_CONVENIO_p  \
# 2895    6073184-1-LIBERTY     490618  RENOVACION CONCESIONARIOS ARTURO ZUÑIGA
# ...

# %%
### FLOTA_CONVENIO

dfp1 = dfp[['KEY', 'SSEGURO', 'FLOTA_CONVENIO']]
dfs1 = dfs[['KEY', 'FLOTA_CONVENIO']]

dfp1['FLOTA_CONVENIO'] = dfp1['FLOTA_CONVENIO'].astype(str).copy()
dfs1['FLOTA_CONVENIO'] = dfs1['FLOTA_CONVENIO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA_CONVENIO_p != dfm.FLOTA_CONVENIO_s) & (~dfm.FLOTA_CONVENIO_s.isnull()) & (~dfm.FLOTA_CONVENIO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FLOTA_CONVENIO_p','FLOTA_CONVENIO_s']]
# Out:
# <ipython-input-68-60b037ac8504>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FLOTA_CONVENIO'] = dfp1['FLOTA_CONVENIO'].astype(str).copy()
# <ipython-input-68-60b037ac8504>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FLOTA_CONVENIO'] = dfs1['FLOTA_CONVENIO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FLOTA_CONVENIO_p, FLOTA_CONVENIO_s]
# Index: []

# %%
### SUCURSAL

dfp1 = dfp[['KEY', 'SSEGURO', 'SUCURSAL']]
dfs1 = dfs[['KEY', 'SUCURSAL']]

dfp1['SUCURSAL'] = dfp1['SUCURSAL'].astype(str).copy()
dfs1['SUCURSAL'] = dfs1['SUCURSAL'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SUCURSAL_p != dfm.SUCURSAL_s) & (~dfm.SUCURSAL_s.isnull()) & (~dfm.SUCURSAL_p.isnull())].copy()
dfm1[['KEY','SSEGURO','SUCURSAL_p','SUCURSAL_s']]
# Out:
# <ipython-input-69-b990db90ab68>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['SUCURSAL'] = dfp1['SUCURSAL'].astype(str).copy()
# <ipython-input-69-b990db90ab68>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['SUCURSAL'] = dfs1['SUCURSAL'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, SUCURSAL_p, SUCURSAL_s]
# Index: []

# %%
### COD_SUCURSAL1

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_SUCURSAL1']]
dfs1 = dfs[['KEY', 'COD_SUCURSAL1']]

dfp1['COD_SUCURSAL1'] = dfp1['COD_SUCURSAL1'].astype(str).copy()
dfs1['COD_SUCURSAL1'] = dfs1['COD_SUCURSAL1'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_SUCURSAL1_p != dfm.COD_SUCURSAL1_s) & (~dfm.COD_SUCURSAL1_s.isnull()) & (~dfm.COD_SUCURSAL1_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_SUCURSAL1_p','COD_SUCURSAL1_s']]
# Out:
# <ipython-input-70-2bbabe0ce866>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_SUCURSAL1'] = dfp1['COD_SUCURSAL1'].astype(str).copy()
# <ipython-input-70-2bbabe0ce866>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_SUCURSAL1'] = dfs1['COD_SUCURSAL1'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COD_SUCURSAL1_p, COD_SUCURSAL1_s]
# Index: []

# %%
### SUMA_ASEG_RC

dfp1 = dfp[['KEY', 'SSEGURO', 'SUMA_ASEG_RC']]
dfs1 = dfs[['KEY', 'SUMA_ASEG_RC']]

dfp1['SUMA_ASEG_RC'] = corregirColumna(dfp1,'SUMA_ASEG_RC')

dfp1['SUMA_ASEG_RC'] = dfp1['SUMA_ASEG_RC'].astype(float).astype(str).copy()
dfs1['SUMA_ASEG_RC'] = dfs1['SUMA_ASEG_RC'].astype(float).astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SUMA_ASEG_RC_p != dfm.SUMA_ASEG_RC_s) & (~dfm.SUMA_ASEG_RC_s.isnull()) & (~dfm.SUMA_ASEG_RC_p.isnull())].copy()
dfm1[['KEY','SSEGURO','SUMA_ASEG_RC_p','SUMA_ASEG_RC_s']]
# Out:
# <ipython-input-71-14f9530cc454>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['SUMA_ASEG_RC'] = corregirColumna(dfp1,'SUMA_ASEG_RC')
# <ipython-input-71-14f9530cc454>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['SUMA_ASEG_RC'] = dfp1['SUMA_ASEG_RC'].astype(float).astype(str).copy()
# <ipython-input-71-14f9530cc454>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
### ORIGEN

dfp1 = dfp[['KEY', 'SSEGURO', 'ORIGEN']]
dfs1 = dfs[['KEY', 'ORIGEN']]

dfp1['ORIGEN'] = dfp1['ORIGEN'].astype(str).copy()
dfs1['ORIGEN'] = dfs1['ORIGEN'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ORIGEN_p != dfm.ORIGEN_s) & (~dfm.ORIGEN_s.isnull()) & (~dfm.ORIGEN_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ORIGEN_p','ORIGEN_s']]
# Out:
# <ipython-input-72-54b2ea574e1d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ORIGEN'] = dfp1['ORIGEN'].astype(str).copy()
# <ipython-input-72-54b2ea574e1d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ORIGEN'] = dfs1['ORIGEN'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, ORIGEN_p, ORIGEN_s]
# Index: []

# %%
### ASEGURADO_RUT

dfp1 = dfp[['KEY', 'SSEGURO', 'ASEGURADO_RUT']]
dfs1 = dfs[['KEY', 'ASEGURADO_RUT']]

dfp1['ASEGURADO_RUT'] = dfp1['ASEGURADO_RUT'].astype(str).copy()
dfs1['ASEGURADO_RUT'] = dfs1['ASEGURADO_RUT'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ASEGURADO_RUT_p != dfm.ASEGURADO_RUT_s) & (~dfm.ASEGURADO_RUT_s.isnull()) & (~dfm.ASEGURADO_RUT_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ASEGURADO_RUT_p','ASEGURADO_RUT_s']]
# Out:
# <ipython-input-73-eb50a5ad1d04>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ASEGURADO_RUT'] = dfp1['ASEGURADO_RUT'].astype(str).copy()
# <ipython-input-73-eb50a5ad1d04>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ASEGURADO_RUT'] = dfs1['ASEGURADO_RUT'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, ASEGURADO_RUT_p, ASEGURADO_RUT_s]
# Index: []

# %%
### ANO_REF_INI

dfp1 = dfp[['KEY', 'SSEGURO', 'ANO_REF_INI']]
dfs1 = dfs[['KEY', 'ANO_REF_INI']]

dfp1['ANO_REF_INI'] = dfp1['ANO_REF_INI'].astype(str).copy()
dfs1['ANO_REF_INI'] = dfs1['ANO_REF_INI'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ANO_REF_INI_p != dfm.ANO_REF_INI_s) & (~dfm.ANO_REF_INI_s.isnull()) & (~dfm.ANO_REF_INI_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ANO_REF_INI_p','ANO_REF_INI_s']]
# Out:
# <ipython-input-74-13195ec06317>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ANO_REF_INI'] = dfp1['ANO_REF_INI'].astype(str).copy()
# <ipython-input-74-13195ec06317>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ANO_REF_INI'] = dfs1['ANO_REF_INI'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, ANO_REF_INI_p, ANO_REF_INI_s]
# Index: []

# %%
### NUM_ITEMS_CONTRA

dfp1 = dfp[['KEY', 'SSEGURO', 'NUM_ITEMS_CONTRA']]
dfs1 = dfs[['KEY', 'NUM_ITEMS_CONTRA']]

dfp1['NUM_ITEMS_CONTRA'] = dfp1['NUM_ITEMS_CONTRA'].astype(str).copy()
dfs1['NUM_ITEMS_CONTRA'] = dfs1['NUM_ITEMS_CONTRA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NUM_ITEMS_CONTRA_p != dfm.NUM_ITEMS_CONTRA_s) & (~dfm.NUM_ITEMS_CONTRA_s.isnull()) & (~dfm.NUM_ITEMS_CONTRA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','NUM_ITEMS_CONTRA_p','NUM_ITEMS_CONTRA_s']]
# Out:
# <ipython-input-75-892f885395c7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['NUM_ITEMS_CONTRA'] = dfp1['NUM_ITEMS_CONTRA'].astype(str).copy()
# <ipython-input-75-892f885395c7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['NUM_ITEMS_CONTRA'] = dfs1['NUM_ITEMS_CONTRA'].astype(str).copy()
#                         KEY    SSEGURO NUM_ITEMS_CONTRA_p NUM_ITEMS_CONTRA_s
# 23800   61097783-20-LIBERTY  907093899               2171               2166
# ...

# %%
### FLOTA_CONTRA

dfp1 = dfp[['KEY', 'SSEGURO', 'FLOTA_CONTRA']]
dfs1 = dfs[['KEY', 'FLOTA_CONTRA']]

dfp1['FLOTA_CONTRA'] = dfp1['FLOTA_CONTRA'].astype(str).copy()
dfs1['FLOTA_CONTRA'] = dfs1['FLOTA_CONTRA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA_CONTRA_p != dfm.FLOTA_CONTRA_s) & (~dfm.FLOTA_CONTRA_s.isnull()) & (~dfm.FLOTA_CONTRA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FLOTA_CONTRA_p','FLOTA_CONTRA_s']]
# Out:
# <ipython-input-76-6bad8fd9b35b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FLOTA_CONTRA'] = dfp1['FLOTA_CONTRA'].astype(str).copy()
# <ipython-input-76-6bad8fd9b35b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FLOTA_CONTRA'] = dfs1['FLOTA_CONTRA'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FLOTA_CONTRA_p, FLOTA_CONTRA_s]
# Index: []

# %%
### COD_CONVENIO

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_CONVENIO']]
dfs1 = dfs[['KEY', 'COD_CONVENIO']]

dfp1['COD_CONVENIO'] = dfp1['COD_CONVENIO'].astype(str).copy()
dfs1['COD_CONVENIO'] = dfs1['COD_CONVENIO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_CONVENIO_p != dfm.COD_CONVENIO_s) & (~dfm.COD_CONVENIO_s.isnull()) & (~dfm.COD_CONVENIO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_CONVENIO_p','COD_CONVENIO_s']]
# Out:
# <ipython-input-77-e1fa72f07763>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_CONVENIO'] = dfp1['COD_CONVENIO'].astype(str).copy()
# <ipython-input-77-e1fa72f07763>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_CONVENIO'] = dfs1['COD_CONVENIO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COD_CONVENIO_p, COD_CONVENIO_s]
# Index: []

# %%
### FLOTA

dfp1 = dfp[['KEY', 'SSEGURO', 'FLOTA']]
dfs1 = dfs[['KEY', 'FLOTA']]

dfp1['FLOTA'] = dfp1['FLOTA'].astype(str).copy()
dfs1['FLOTA'] = dfs1['FLOTA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA_p != dfm.FLOTA_s) & (~dfm.FLOTA_s.isnull()) & (~dfm.FLOTA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FLOTA_p','FLOTA_s']]
# Out:
# <ipython-input-78-b4f57070d804>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FLOTA'] = dfp1['FLOTA'].astype(str).copy()
# <ipython-input-78-b4f57070d804>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FLOTA'] = dfs1['FLOTA'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FLOTA_p, FLOTA_s]
# Index: []

# %%
### COD_SUCURSAL

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_SUCURSAL']]
dfs1 = dfs[['KEY', 'COD_SUCURSAL']]

dfp1['COD_SUCURSAL'] = dfp1['COD_SUCURSAL'].astype(str).copy()
dfs1['COD_SUCURSAL'] = dfs1['COD_SUCURSAL'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_SUCURSAL_p != dfm.COD_SUCURSAL_s) & (~dfm.COD_SUCURSAL_s.isnull()) & (~dfm.COD_SUCURSAL_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_SUCURSAL_p','COD_SUCURSAL_s']]
# Out:
# <ipython-input-79-80f4d25b5b5f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_SUCURSAL'] = dfp1['COD_SUCURSAL'].astype(str).copy()
# <ipython-input-79-80f4d25b5b5f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_SUCURSAL'] = dfs1['COD_SUCURSAL'].astype(str).copy()
#                       KEY    SSEGURO COD_SUCURSAL_p COD_SUCURSAL_s
# 3       6014916-2-LIBERTY     467783            499             **
# ...

# %%
### LC_MODEL

dfp1 = dfp[['KEY', 'SSEGURO', 'LC_MODEL']]
dfs1 = dfs[['KEY', 'LC_MODEL']]

dfp1['LC_MODEL'] = dfp1['LC_MODEL'].astype(str).copy()
dfs1['LC_MODEL'] = dfs1['LC_MODEL'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.LC_MODEL_p != dfm.LC_MODEL_s) & (~dfm.LC_MODEL_s.isnull()) & (~dfm.LC_MODEL_p.isnull())].copy()
dfm1[['KEY','SSEGURO','LC_MODEL_p','LC_MODEL_s']]
# Out:
# <ipython-input-80-382a945a58db>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['LC_MODEL'] = dfp1['LC_MODEL'].astype(str).copy()
# <ipython-input-80-382a945a58db>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['LC_MODEL'] = dfs1['LC_MODEL'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, LC_MODEL_p, LC_MODEL_s]
# Index: []

# %%
### LC_MODEL_DEF

dfp1 = dfp[['KEY', 'SSEGURO', 'LC_MODEL_DEF']]
dfs1 = dfs[['KEY', 'LC_MODEL_DEF']]

dfp1['LC_MODEL_DEF'] = dfp1['LC_MODEL_DEF'].astype(str).copy()
dfs1['LC_MODEL_DEF'] = dfs1['LC_MODEL_DEF'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.LC_MODEL_DEF_p != dfm.LC_MODEL_DEF_s) & (~dfm.LC_MODEL_DEF_s.isnull()) & (~dfm.LC_MODEL_DEF_p.isnull())].copy()
dfm1[['KEY','SSEGURO','LC_MODEL_DEF_p','LC_MODEL_DEF_s']]
# Out:
# <ipython-input-81-d85688c2b154>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['LC_MODEL_DEF'] = dfp1['LC_MODEL_DEF'].astype(str).copy()
# <ipython-input-81-d85688c2b154>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['LC_MODEL_DEF'] = dfs1['LC_MODEL_DEF'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, LC_MODEL_DEF_p, LC_MODEL_DEF_s]
# Index: []

# %%
### MES_REF_INI

dfp1 = dfp[['KEY', 'SSEGURO', 'MES_REF_INI']]
dfs1 = dfs[['KEY', 'MES_REF_INI']]

dfp1['MES_REF_INI'] = dfp1['MES_REF_INI'].astype(str).copy()
dfs1['MES_REF_INI'] = dfs1['MES_REF_INI'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.MES_REF_INI_p != dfm.MES_REF_INI_s) & (~dfm.MES_REF_INI_s.isnull()) & (~dfm.MES_REF_INI_p.isnull())].copy()
dfm1[['KEY','SSEGURO','MES_REF_INI_p','MES_REF_INI_s']]
# Out:
# <ipython-input-82-9c8340ece83e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['MES_REF_INI'] = dfp1['MES_REF_INI'].astype(str).copy()
# <ipython-input-82-9c8340ece83e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['MES_REF_INI'] = dfs1['MES_REF_INI'].astype(str).copy()
#                        KEY    SSEGURO MES_REF_INI_p MES_REF_INI_s
# 0      6006870-111-LIBERTY     668744        201005           nan
# 1        6013563-9-LIBERTY     489217        201001           nan
# ...

# %%
### PRIMA_RECIBO

dfp1 = dfp[['KEY', 'SSEGURO', 'PRIMA_RECIBO']]
dfs1 = dfs[['KEY', 'PRIMA_RECIBO']]

dfp1['PRIMA_RECIBO'] = dfp1['PRIMA_RECIBO'].astype(str).copy()
dfs1['PRIMA_RECIBO'] = dfs1['PRIMA_RECIBO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_RECIBO_p != dfm.PRIMA_RECIBO_s) & (~dfm.PRIMA_RECIBO_s.isnull()) & (~dfm.PRIMA_RECIBO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PRIMA_RECIBO_p','PRIMA_RECIBO_s']]
# Out:
# <ipython-input-83-92a8092d607c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PRIMA_RECIBO'] = dfp1['PRIMA_RECIBO'].astype(str).copy()
# <ipython-input-83-92a8092d607c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PRIMA_RECIBO'] = dfs1['PRIMA_RECIBO'].astype(str).copy()
#                        KEY    SSEGURO PRIMA_RECIBO_p PRIMA_RECIBO_s
# 0      6006870-111-LIBERTY     668744      12.824324          12.82
# ...

# %%
### PRIMA_RECIBO_FINAL

dfp1 = dfp[['KEY', 'SSEGURO', 'PRIMA_RECIBO_FINAL']]
dfs1 = dfs[['KEY', 'PRIMA_RECIBO_FINAL']]

dfp1['PRIMA_RECIBO_FINAL'] = dfp1['PRIMA_RECIBO_FINAL'].astype(str).copy()
dfs1['PRIMA_RECIBO_FINAL'] = dfs1['PRIMA_RECIBO_FINAL'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_RECIBO_FINAL_p != dfm.PRIMA_RECIBO_FINAL_s) & (~dfm.PRIMA_RECIBO_FINAL_s.isnull()) & (~dfm.PRIMA_RECIBO_FINAL_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PRIMA_RECIBO_FINAL_p','PRIMA_RECIBO_FINAL_s']]
# Out:
# <ipython-input-84-016fa39b0f2f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PRIMA_RECIBO_FINAL'] = dfp1['PRIMA_RECIBO_FINAL'].astype(str).copy()
# <ipython-input-84-016fa39b0f2f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PRIMA_RECIBO_FINAL'] = dfs1['PRIMA_RECIBO_FINAL'].astype(str).copy()
#                        KEY    SSEGURO PRIMA_RECIBO_FINAL_p  \
# 0      6006870-111-LIBERTY     668744             6.412162
# ...

# %%
### COB_INI

dfp1 = dfp[['KEY', 'SSEGURO', 'COB_INI']]
dfs1 = dfs[['KEY', 'COB_INI']]

dfp1['COB_INI'] = dfp1['COB_INI'].astype(str).copy()
dfs1['COB_INI'] = dfs1['COB_INI'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COB_INI_p != dfm.COB_INI_s) & (~dfm.COB_INI_s.isnull()) & (~dfm.COB_INI_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COB_INI_p','COB_INI_s']]
# Out:
# <ipython-input-85-a8d82fec7a7f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COB_INI'] = dfp1['COB_INI'].astype(str).copy()
# <ipython-input-85-a8d82fec7a7f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COB_INI'] = dfs1['COB_INI'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COB_INI_p, COB_INI_s]
# Index: []

# %%
### COB_FIN

dfp1 = dfp[['KEY', 'SSEGURO', 'COB_FIN']]
dfs1 = dfs[['KEY', 'COB_FIN']]

dfp1['COB_FIN'] = dfp1['COB_FIN'].astype(str).copy()
dfs1['COB_FIN'] = dfs1['COB_FIN'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COB_FIN_p != dfm.COB_FIN_s) & (~dfm.COB_FIN_s.isnull()) & (~dfm.COB_FIN_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COB_FIN_p','COB_FIN_s']]
# Out:
# <ipython-input-86-c27e3acd69c9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COB_FIN'] = dfp1['COB_FIN'].astype(str).copy()
# <ipython-input-86-c27e3acd69c9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COB_FIN'] = dfs1['COB_FIN'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COB_FIN_p, COB_FIN_s]
# Index: []

# %%
### FECHA_COTRENOV

dfp1 = dfp[['KEY', 'SSEGURO', 'FECHA_COTRENOV']]
dfs1 = dfs[['KEY', 'FECHA_COTRENOV']]

dfp1['FECHA_COTRENOV'] = dfp1['FECHA_COTRENOV'].astype(str).copy()
dfs1['FECHA_COTRENOV'] = dfs1['FECHA_COTRENOV'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FECHA_COTRENOV_p != dfm.FECHA_COTRENOV_s) & (~dfm.FECHA_COTRENOV_s.isnull()) & (~dfm.FECHA_COTRENOV_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FECHA_COTRENOV_p','FECHA_COTRENOV_s']]
# Out:
# <ipython-input-87-c8082b4be497>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FECHA_COTRENOV'] = dfp1['FECHA_COTRENOV'].astype(str).copy()
# <ipython-input-87-c8082b4be497>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FECHA_COTRENOV'] = dfs1['FECHA_COTRENOV'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FECHA_COTRENOV_p, FECHA_COTRENOV_s]
# Index: []

# %%
### PLAN_DESC

dfp1 = dfp[['KEY', 'SSEGURO', 'PLAN_DESC']]
dfs1 = dfs[['KEY', 'PLAN_DESC']]

dfp1['PLAN_DESC'] = dfp1['PLAN_DESC'].astype(str).copy()
dfs1['PLAN_DESC'] = dfs1['PLAN_DESC'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PLAN_DESC_p != dfm.PLAN_DESC_s) & (~dfm.PLAN_DESC_s.isnull()) & (~dfm.PLAN_DESC_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PLAN_DESC_p','PLAN_DESC_s']]
# Out:
# <ipython-input-88-661768cece28>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PLAN_DESC'] = dfp1['PLAN_DESC'].astype(str).copy()
# <ipython-input-88-661768cece28>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PLAN_DESC'] = dfs1['PLAN_DESC'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, PLAN_DESC_p, PLAN_DESC_s]
# Index: []

# %%
### TIPO_PLAN

dfp1 = dfp[['KEY', 'SSEGURO', 'TIPO_PLAN']]
dfs1 = dfs[['KEY', 'TIPO_PLAN']]

dfp1['TIPO_PLAN'] = dfp1['TIPO_PLAN'].astype(str).copy()
dfs1['TIPO_PLAN'] = dfs1['TIPO_PLAN'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TIPO_PLAN_p != dfm.TIPO_PLAN_s) & (~dfm.TIPO_PLAN_s.isnull()) & (~dfm.TIPO_PLAN_p.isnull())].copy()
dfm1[['KEY','SSEGURO','TIPO_PLAN_p','TIPO_PLAN_s']]
# Out:
# <ipython-input-89-6d3d7a5b80d9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['TIPO_PLAN'] = dfp1['TIPO_PLAN'].astype(str).copy()
# <ipython-input-89-6d3d7a5b80d9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['TIPO_PLAN'] = dfs1['TIPO_PLAN'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, TIPO_PLAN_p, TIPO_PLAN_s]
# Index: []

# %%
### ANTERIOR

dfp1 = dfp[['KEY', 'SSEGURO', 'ANTERIOR']]
dfs1 = dfs[['KEY', 'ANTERIOR']]

dfp1['ANTERIOR'] = dfp1['ANTERIOR'].astype(str).copy()
dfs1['ANTERIOR'] = dfs1['ANTERIOR'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ANTERIOR_p != dfm.ANTERIOR_s) & (~dfm.ANTERIOR_s.isnull()) & (~dfm.ANTERIOR_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ANTERIOR_p','ANTERIOR_s']]
# Out:
# <ipython-input-90-1fd5b1608581>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ANTERIOR'] = dfp1['ANTERIOR'].astype(str).copy()
# <ipython-input-90-1fd5b1608581>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ANTERIOR'] = dfs1['ANTERIOR'].astype(str).copy()
#                        KEY    SSEGURO ANTERIOR_p ANTERIOR_s
# 54       6035900-4-LIBERTY     809036   EX PENTA         NO
# 70       6038454-2-LIBERTY     555399   EX PENTA         NO
# ...

# %%
### NUM_ITEMS

dfp1 = dfp[['KEY', 'SSEGURO', 'NUM_ITEMS']]
dfs1 = dfs[['KEY', 'NUM_ITEMS']]

dfp1['NUM_ITEMS'] = dfp1['NUM_ITEMS'].astype(str).copy()
dfs1['NUM_ITEMS'] = dfs1['NUM_ITEMS'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NUM_ITEMS_p != dfm.NUM_ITEMS_s) & (~dfm.NUM_ITEMS_s.isnull()) & (~dfm.NUM_ITEMS_p.isnull())].copy()
dfm1[['KEY','SSEGURO','NUM_ITEMS_p','NUM_ITEMS_s']]
# Out:
# <ipython-input-91-fdda43fcb98b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['NUM_ITEMS'] = dfp1['NUM_ITEMS'].astype(str).copy()
# <ipython-input-91-fdda43fcb98b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['NUM_ITEMS'] = dfs1['NUM_ITEMS'].astype(str).copy()
#                          KEY    SSEGURO NUM_ITEMS_p NUM_ITEMS_s
# 34602    61185197-10-LIBERTY  904343644        1157        1152
# 34603  61185197-1007-LIBERTY  907313098        1157        1152
# ...

# %%
### COD_MARCA_P

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_MARCA_P']]
dfs1 = dfs[['KEY', 'COD_MARCA_P']]

dfp1['COD_MARCA_P'] = dfp1['COD_MARCA_P'].astype(str).copy()
dfs1['COD_MARCA_P'] = dfs1['COD_MARCA_P'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_MARCA_P_p != dfm.COD_MARCA_P_s) & (~dfm.COD_MARCA_P_s.isnull()) & (~dfm.COD_MARCA_P_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_MARCA_P_p','COD_MARCA_P_s']]
# Out:
# <ipython-input-92-9e5ac4d95c2e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_MARCA_P'] = dfp1['COD_MARCA_P'].astype(str).copy()
# <ipython-input-92-9e5ac4d95c2e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_MARCA_P'] = dfs1['COD_MARCA_P'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COD_MARCA_P_p, COD_MARCA_P_s]
# Index: []

# %%
### COD_MODELO_P

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_MODELO_P']]
dfs1 = dfs[['KEY', 'COD_MODELO_P']]

dfp1['COD_MODELO_P'] = dfp1['COD_MODELO_P'].astype(str).copy()
dfs1['COD_MODELO_P'] = dfs1['COD_MODELO_P'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_MODELO_P_p != dfm.COD_MODELO_P_s) & (~dfm.COD_MODELO_P_s.isnull()) & (~dfm.COD_MODELO_P_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_MODELO_P_p','COD_MODELO_P_s']]
# Out:
# <ipython-input-93-9268faadfb6e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_MODELO_P'] = dfp1['COD_MODELO_P'].astype(str).copy()
# <ipython-input-93-9268faadfb6e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_MODELO_P'] = dfs1['COD_MODELO_P'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COD_MODELO_P_p, COD_MODELO_P_s]
# Index: []

# %%
### COD_TIPO_P

dfp1 = dfp[['KEY', 'SSEGURO', 'COD_TIPO_P']]
dfs1 = dfs[['KEY', 'COD_TIPO_P']]

dfp1['COD_TIPO_P'] = dfp1['COD_TIPO_P'].astype(str).copy()
dfs1['COD_TIPO_P'] = dfs1['COD_TIPO_P'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_TIPO_P_p != dfm.COD_TIPO_P_s) & (~dfm.COD_TIPO_P_s.isnull()) & (~dfm.COD_TIPO_P_p.isnull())].copy()
dfm1[['KEY','SSEGURO','COD_TIPO_P_p','COD_TIPO_P_s']]
# Out:
# <ipython-input-94-83f9ead3c726>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['COD_TIPO_P'] = dfp1['COD_TIPO_P'].astype(str).copy()
# <ipython-input-94-83f9ead3c726>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['COD_TIPO_P'] = dfs1['COD_TIPO_P'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, COD_TIPO_P_p, COD_TIPO_P_s]
# Index: []

# %%
### CANAL

dfp1 = dfp[['KEY', 'SSEGURO', 'CANAL']]
dfs1 = dfs[['KEY', 'CANAL']]

dfp1['CANAL'] = dfp1['CANAL'].astype(str).copy()
dfs1['CANAL'] = dfs1['CANAL'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CANAL_p != dfm.CANAL_s) & (~dfm.CANAL_s.isnull()) & (~dfm.CANAL_p.isnull())].copy()
dfm1[['KEY','SSEGURO','CANAL_p','CANAL_s']]
# Out:
# <ipython-input-95-d58e63eb3db5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['CANAL'] = dfp1['CANAL'].astype(str).copy()
# <ipython-input-95-d58e63eb3db5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['CANAL'] = dfs1['CANAL'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, CANAL_p, CANAL_s]
# Index: []

# %%
### DURACION_PLAN

dfp1 = dfp[['KEY', 'SSEGURO', 'DURACION_PLAN']]
dfs1 = dfs[['KEY', 'DURACION_PLAN']]

dfp1['DURACION_PLAN'] = dfp1['DURACION_PLAN'].astype(str).copy()
dfs1['DURACION_PLAN'] = dfs1['DURACION_PLAN'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DURACION_PLAN_p != dfm.DURACION_PLAN_s) & (~dfm.DURACION_PLAN_s.isnull()) & (~dfm.DURACION_PLAN_p.isnull())].copy()
dfm1[['KEY','SSEGURO','DURACION_PLAN_p','DURACION_PLAN_s']]
# Out:
# <ipython-input-96-281c563b18ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['DURACION_PLAN'] = dfp1['DURACION_PLAN'].astype(str).copy()
# <ipython-input-96-281c563b18ea>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['DURACION_PLAN'] = dfs1['DURACION_PLAN'].astype(str).copy()
#                        KEY    SSEGURO   DURACION_PLAN_p DURACION_PLAN_s
# 153    6049507-350-LIBERTY     571163  ENTRE 1 Y 2 ANOS           1 ANO
# ...

# %%
### ORIGEN_MARCA

dfp1 = dfp[['KEY', 'SSEGURO', 'ORIGEN_MARCA']]
dfs1 = dfs[['KEY', 'ORIGEN_MARCA']]

dfp1['ORIGEN_MARCA'] = dfp1['ORIGEN_MARCA'].astype(str).copy()
dfs1['ORIGEN_MARCA'] = dfs1['ORIGEN_MARCA'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ORIGEN_MARCA_p != dfm.ORIGEN_MARCA_s) & (~dfm.ORIGEN_MARCA_s.isnull()) & (~dfm.ORIGEN_MARCA_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ORIGEN_MARCA_p','ORIGEN_MARCA_s']]
# Out:
# <ipython-input-97-a88a1d697192>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ORIGEN_MARCA'] = dfp1['ORIGEN_MARCA'].astype(str).copy()
# <ipython-input-97-a88a1d697192>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ORIGEN_MARCA'] = dfs1['ORIGEN_MARCA'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, ORIGEN_MARCA_p, ORIGEN_MARCA_s]
# Index: []

# %%
### ANTIG_VEHICULO

dfp1 = dfp[['KEY', 'SSEGURO', 'ANTIG_VEHICULO']]
dfs1 = dfs[['KEY', 'ANTIG_VEHICULO']]

dfp1['ANTIG_VEHICULO'] = dfp1['ANTIG_VEHICULO'].astype(str).copy()
dfs1['ANTIG_VEHICULO'] = dfs1['ANTIG_VEHICULO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ANTIG_VEHICULO_p != dfm.ANTIG_VEHICULO_s) & (~dfm.ANTIG_VEHICULO_s.isnull()) & (~dfm.ANTIG_VEHICULO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','ANTIG_VEHICULO_p','ANTIG_VEHICULO_s']]
# Out:
# <ipython-input-98-3f39a971544d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['ANTIG_VEHICULO'] = dfp1['ANTIG_VEHICULO'].astype(str).copy()
# <ipython-input-98-3f39a971544d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['ANTIG_VEHICULO'] = dfs1['ANTIG_VEHICULO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, ANTIG_VEHICULO_p, ANTIG_VEHICULO_s]
# Index: []

# %%
### PT_RO

dfp1 = dfp[['KEY', 'SSEGURO', 'PT_RO']]
dfs1 = dfs[['KEY', 'PT_RO']]

dfp1['PT_RO'] = dfp1['PT_RO'].astype(str).copy()
dfs1['PT_RO'] = dfs1['PT_RO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PT_RO_p != dfm.PT_RO_s) & (~dfm.PT_RO_s.isnull()) & (~dfm.PT_RO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','PT_RO_p','PT_RO_s']]
# Out:
# <ipython-input-99-f5588a606ff4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['PT_RO'] = dfp1['PT_RO'].astype(str).copy()
# <ipython-input-99-f5588a606ff4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['PT_RO'] = dfs1['PT_RO'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, PT_RO_p, PT_RO_s]
# Index: []

# %%
### DATE_UPDATE

dfp1 = dfp[['KEY', 'SSEGURO', 'DATE_UPDATE']]
dfs1 = dfs[['KEY', 'DATE_UPDATE']]

dfp1['DATE_UPDATE'] = dfp1['DATE_UPDATE'].astype(str).copy()
dfs1['DATE_UPDATE'] = dfs1['DATE_UPDATE'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DATE_UPDATE_p != dfm.DATE_UPDATE_s) & (~dfm.DATE_UPDATE_s.isnull()) & (~dfm.DATE_UPDATE_p.isnull())].copy()
dfm1[['KEY','SSEGURO','DATE_UPDATE_p','DATE_UPDATE_s']]
# Out:
# <ipython-input-100-63c32d97f4aa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['DATE_UPDATE'] = dfp1['DATE_UPDATE'].astype(str).copy()
# <ipython-input-100-63c32d97f4aa>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['DATE_UPDATE'] = dfs1['DATE_UPDATE'].astype(str).copy()
#                        KEY    SSEGURO DATE_UPDATE_p DATE_UPDATE_s
# 0      6006870-111-LIBERTY     668744    2022-06-14    2022-06-05
# 1        6013563-9-LIBERTY     489217    2022-06-14    2022-06-05
# ...

# %%
### FORMA_PAGO_INI

dfp1 = dfp[['KEY', 'SSEGURO', 'FORMA_PAGO_INI']]
dfs1 = dfs[['KEY', 'FORMA_PAGO_INI']]

dfp1['FORMA_PAGO_INI'] = dfp1['FORMA_PAGO_INI'].astype(str).copy()
dfs1['FORMA_PAGO_INI'] = dfs1['FORMA_PAGO_INI'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FORMA_PAGO_INI_p != dfm.FORMA_PAGO_INI_s) & (~dfm.FORMA_PAGO_INI_s.isnull()) & (~dfm.FORMA_PAGO_INI_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FORMA_PAGO_INI_p','FORMA_PAGO_INI_s']]
# Out:
# <ipython-input-101-7d8fbb6d6991>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FORMA_PAGO_INI'] = dfp1['FORMA_PAGO_INI'].astype(str).copy()
# <ipython-input-101-7d8fbb6d6991>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FORMA_PAGO_INI'] = dfs1['FORMA_PAGO_INI'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FORMA_PAGO_INI_p, FORMA_PAGO_INI_s]
# Index: []

# %%
### FORMA_PAGO_FIN

dfp1 = dfp[['KEY', 'SSEGURO', 'FORMA_PAGO_FIN']]
dfs1 = dfs[['KEY', 'FORMA_PAGO_FIN']]

dfp1['FORMA_PAGO_FIN'] = dfp1['FORMA_PAGO_FIN'].astype(str).copy()
dfs1['FORMA_PAGO_FIN'] = dfs1['FORMA_PAGO_FIN'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FORMA_PAGO_FIN_p != dfm.FORMA_PAGO_FIN_s) & (~dfm.FORMA_PAGO_FIN_s.isnull()) & (~dfm.FORMA_PAGO_FIN_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FORMA_PAGO_FIN_p','FORMA_PAGO_FIN_s']]
# Out:
# <ipython-input-102-936af960e696>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FORMA_PAGO_FIN'] = dfp1['FORMA_PAGO_FIN'].astype(str).copy()
# <ipython-input-102-936af960e696>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FORMA_PAGO_FIN'] = dfs1['FORMA_PAGO_FIN'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, FORMA_PAGO_FIN_p, FORMA_PAGO_FIN_s]
# Index: []

# %%
### METODO_PAGO

dfp1 = dfp[['KEY', 'SSEGURO', 'METODO_PAGO']]
dfs1 = dfs[['KEY', 'METODO_PAGO']]

dfp1['METODO_PAGO'] = dfp1['METODO_PAGO'].astype(str).copy()
dfs1['METODO_PAGO'] = dfs1['METODO_PAGO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.METODO_PAGO_p != dfm.METODO_PAGO_s) & (~dfm.METODO_PAGO_s.isnull()) & (~dfm.METODO_PAGO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','METODO_PAGO_p','METODO_PAGO_s']]
# Out:
# <ipython-input-103-4b66a5fc6cef>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['METODO_PAGO'] = dfp1['METODO_PAGO'].astype(str).copy()
# <ipython-input-103-4b66a5fc6cef>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['METODO_PAGO'] = dfs1['METODO_PAGO'].astype(str).copy()
#                       KEY    SSEGURO METODO_PAGO_p METODO_PAGO_s
# 1       6013563-9-LIBERTY     489217           nan      CUPONERA
# 16      6025546-3-LIBERTY     586519           nan  PAGO CONTADO
# ...

# %%
### RAZON_CUOTAS

dfp1 = dfp[['KEY', 'SSEGURO', 'RAZON_CUOTAS']]
dfs1 = dfs[['KEY', 'RAZON_CUOTAS']]

dfp1['RAZON_CUOTAS'] = dfp1['RAZON_CUOTAS'].astype(str).copy()
dfs1['RAZON_CUOTAS'] = dfs1['RAZON_CUOTAS'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.RAZON_CUOTAS_p != dfm.RAZON_CUOTAS_s) & (~dfm.RAZON_CUOTAS_s.isnull()) & (~dfm.RAZON_CUOTAS_p.isnull())].copy()
dfm1[['KEY','SSEGURO','RAZON_CUOTAS_p','RAZON_CUOTAS_s']]
# Out:
# <ipython-input-104-0241036f438d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['RAZON_CUOTAS'] = dfp1['RAZON_CUOTAS'].astype(str).copy()
# <ipython-input-104-0241036f438d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['RAZON_CUOTAS'] = dfs1['RAZON_CUOTAS'].astype(str).copy()
#                       KEY  SSEGURO   RAZON_CUOTAS_p         RAZON_CUOTAS_s
# 2      6014329-19-LIBERTY   789926  Redocumentación        Redocumentacion
# ...

# %%
### TUVO_PT

dfp1 = dfp[['KEY', 'SSEGURO', 'TUVO_PT']]
dfs1 = dfs[['KEY', 'TUVO_PT']]

dfp1['TUVO_PT'] = dfp1['TUVO_PT'].astype(str).copy()
dfs1['TUVO_PT'] = dfs1['TUVO_PT'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TUVO_PT_p != dfm.TUVO_PT_s) & (~dfm.TUVO_PT_s.isnull()) & (~dfm.TUVO_PT_p.isnull())].copy()
dfm1[['KEY','SSEGURO','TUVO_PT_p','TUVO_PT_s']]
# Out:
# <ipython-input-105-4603868c9eb6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['TUVO_PT'] = dfp1['TUVO_PT'].astype(str).copy()
# <ipython-input-105-4603868c9eb6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['TUVO_PT'] = dfs1['TUVO_PT'].astype(str).copy()
#                         KEY    SSEGURO TUVO_PT_p TUVO_PT_s
# 429    6063061-1468-LIBERTY     584622       nan         1
# 538    6063061-2356-LIBERTY     766423       nan         1
# ...

# %%
### FORMA_PAGO_DEF

dfp1 = dfp[['KEY', 'SSEGURO', 'FORMA_PAGO_DEF']]
dfs1 = dfs[['KEY', 'FORMA_PAGO_DEF']]

dfp1['FORMA_PAGO_DEF'] = dfp1['FORMA_PAGO_DEF'].astype(str).copy()
dfs1['FORMA_PAGO_DEF'] = dfs1['FORMA_PAGO_DEF'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FORMA_PAGO_DEF_p != dfm.FORMA_PAGO_DEF_s) & (~dfm.FORMA_PAGO_DEF_s.isnull()) & (~dfm.FORMA_PAGO_DEF_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FORMA_PAGO_DEF_p','FORMA_PAGO_DEF_s']]
# Out:
# <ipython-input-106-463708e2cba3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FORMA_PAGO_DEF'] = dfp1['FORMA_PAGO_DEF'].astype(str).copy()
# <ipython-input-106-463708e2cba3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FORMA_PAGO_DEF'] = dfs1['FORMA_PAGO_DEF'].astype(str).copy()
#                       KEY    SSEGURO FORMA_PAGO_DEF_p FORMA_PAGO_DEF_s
# 2061    6068105-1-LIBERTY     438933     PAGO CONTADO      AVISO CUOTA
# ...

# %% [markdown]
# ### MOTIVO_CANCEL_ANUL
#
# dfp1 = dfp[['KEY', 'SSEGURO', 'MOTIVO_CANCEL_ANUL']]
# dfs1 = dfs[['KEY', 'MOTIVO_CANCEL_ANUL']]
#
# dfp1['MOTIVO_CANCEL_ANUL'] = dfp1['MOTIVO_CANCEL_ANUL'].astype(str).copy()
# dfs1['MOTIVO_CANCEL_ANUL'] = dfs1['MOTIVO_CANCEL_ANUL'].astype(str).copy()
#
# dfm = pd.merge(dfp1, dfs1, how='left',
#   left_on=['KEY'],
#   right_on=['KEY'],
#   left_index=False,
#   right_index=False,
#   sort=True,
#  suffixes=('_p', '_s'), copy=True, indicator=False,
#  validate=None)
#
# dfm1 = dfm.sort_values(['KEY'], ascending=[True])
# dfm1 = dfm1.loc[(dfm.MOTIVO_CANCEL_ANUL_p != dfm.MOTIVO_CANCEL_ANUL_s) & (~dfm.MOTIVO_CANCEL_ANUL_s.isnull()) & (~dfm.MOTIVO_CANCEL_ANUL_p.isnull())].copy()
# dfm1[['KEY','SSEGURO','MOTIVO_CANCEL_ANUL_p','MOTIVO_CANCEL_ANUL_s']]

# %%
### TIPO_PERS

dfp1 = dfp[['KEY', 'SSEGURO', 'TIPO_PERS']]
dfs1 = dfs[['KEY', 'TIPO_PERS']]

dfp1['TIPO_PERS'] = dfp1['TIPO_PERS'].astype(str).copy()
dfs1['TIPO_PERS'] = dfs1['TIPO_PERS'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TIPO_PERS_p != dfm.TIPO_PERS_s) & (~dfm.TIPO_PERS_s.isnull()) & (~dfm.TIPO_PERS_p.isnull())].copy()
dfm1[['KEY','SSEGURO','TIPO_PERS_p','TIPO_PERS_s']]
# Out:
# <ipython-input-107-a5239b28ac26>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['TIPO_PERS'] = dfp1['TIPO_PERS'].astype(str).copy()
# <ipython-input-107-a5239b28ac26>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['TIPO_PERS'] = dfs1['TIPO_PERS'].astype(str).copy()
# Empty DataFrame
# Columns: [KEY, SSEGURO, TIPO_PERS_p, TIPO_PERS_s]
# Index: []

# %%
### SEXO

dfp1 = dfp[['KEY', 'SSEGURO', 'SEXO']]
dfs1 = dfs[['KEY', 'SEXO']]

dfp1['SEXO'] = dfp1['SEXO'].astype(str).copy()
dfs1['SEXO'] = dfs1['SEXO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SEXO_p != dfm.SEXO_s) & (~dfm.SEXO_s.isnull()) & (~dfm.SEXO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','SEXO_p','SEXO_s']]
# Out:
# <ipython-input-108-fa3ce129d2cb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['SEXO'] = dfp1['SEXO'].astype(str).copy()
# <ipython-input-108-fa3ce129d2cb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['SEXO'] = dfs1['SEXO'].astype(str).copy()
#                         KEY    SSEGURO SEXO_p SEXO_s
# 110       6044115-2-LIBERTY     671477      0      1
# 1054   6063062-4145-LIBERTY     627533      0      1
# 2064      6068114-2-LIBERTY     945196      1      0
# ...

# %%
### NACIONALIDAD

dfp1 = dfp[['KEY', 'SSEGURO', 'NACIONALIDAD']]
dfs1 = dfs[['KEY', 'NACIONALIDAD']]

dfp1['NACIONALIDAD'] = dfp1['NACIONALIDAD'].astype(str).copy()
dfs1['NACIONALIDAD'] = dfs1['NACIONALIDAD'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NACIONALIDAD_p != dfm.NACIONALIDAD_s) & (~dfm.NACIONALIDAD_s.isnull()) & (~dfm.NACIONALIDAD_p.isnull())].copy()
dfm1[['KEY','SSEGURO','NACIONALIDAD_p','NACIONALIDAD_s']]
# Out:
# <ipython-input-109-e4cac2dec1b5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['NACIONALIDAD'] = dfp1['NACIONALIDAD'].astype(str).copy()
# <ipython-input-109-e4cac2dec1b5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['NACIONALIDAD'] = dfs1['NACIONALIDAD'].astype(str).copy()
#                         KEY    SSEGURO NACIONALIDAD_p NACIONALIDAD_s
# 110       6044115-2-LIBERTY     671477            nan              C
# ...

# %%
### SEXO_ASEGURADO

dfp1 = dfp[['KEY', 'SSEGURO', 'SEXO_ASEGURADO']]
dfs1 = dfs[['KEY', 'SEXO_ASEGURADO']]

dfp1['SEXO_ASEGURADO'] = dfp1['SEXO_ASEGURADO'].astype(str).copy()
dfs1['SEXO_ASEGURADO'] = dfs1['SEXO_ASEGURADO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SEXO_ASEGURADO_p != dfm.SEXO_ASEGURADO_s) & (~dfm.SEXO_ASEGURADO_s.isnull()) & (~dfm.SEXO_ASEGURADO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','SEXO_ASEGURADO_p','SEXO_ASEGURADO_s']]
# Out:
# <ipython-input-110-af0a56559c3f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['SEXO_ASEGURADO'] = dfp1['SEXO_ASEGURADO'].astype(str).copy()
# <ipython-input-110-af0a56559c3f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['SEXO_ASEGURADO'] = dfs1['SEXO_ASEGURADO'].astype(str).copy()
#                         KEY    SSEGURO SEXO_ASEGURADO_p SEXO_ASEGURADO_s
# 110       6044115-2-LIBERTY     671477                M                F
# ...

# %%
### FECHA_NACIMIENTO

dfp1 = dfp[['KEY', 'SSEGURO', 'FECHA_NACIMIENTO']]
dfs1 = dfs[['KEY', 'FECHA_NACIMIENTO']]

dfp1['FECHA_NACIMIENTO'] = dfp1['FECHA_NACIMIENTO'].astype(str).copy()
dfs1['FECHA_NACIMIENTO'] = dfs1['FECHA_NACIMIENTO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FECHA_NACIMIENTO_p != dfm.FECHA_NACIMIENTO_s) & (~dfm.FECHA_NACIMIENTO_s.isnull()) & (~dfm.FECHA_NACIMIENTO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','FECHA_NACIMIENTO_p','FECHA_NACIMIENTO_s']]
# Out:
# <ipython-input-111-5927648b4d91>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['FECHA_NACIMIENTO'] = dfp1['FECHA_NACIMIENTO'].astype(str).copy()
# <ipython-input-111-5927648b4d91>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['FECHA_NACIMIENTO'] = dfs1['FECHA_NACIMIENTO'].astype(str).copy()
#                        KEY    SSEGURO FECHA_NACIMIENTO_p FECHA_NACIMIENTO_s
# 60       6037639-2-LIBERTY     556915         1945-09-21         1945-09-22
# ...

# %%
### EDAD_ASEGURADO

dfp1 = dfp[['KEY', 'SSEGURO', 'EDAD_ASEGURADO']]
dfs1 = dfs[['KEY', 'EDAD_ASEGURADO']]

dfp1['EDAD_ASEGURADO'] = dfp1['EDAD_ASEGURADO'].astype(str).copy()
dfs1['EDAD_ASEGURADO'] = dfs1['EDAD_ASEGURADO'].astype(str).copy()

dfm = pd.merge(dfp1, dfs1, how='left',
  left_on=['KEY'],
  right_on=['KEY'],
  left_index=False,
  right_index=False, 
  sort=True,
 suffixes=('_p', '_s'), copy=True, indicator=False,
 validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.EDAD_ASEGURADO_p != dfm.EDAD_ASEGURADO_s) & (~dfm.EDAD_ASEGURADO_s.isnull()) & (~dfm.EDAD_ASEGURADO_p.isnull())].copy()
dfm1[['KEY','SSEGURO','EDAD_ASEGURADO_p','EDAD_ASEGURADO_s']]
# Out:
# <ipython-input-112-f7adde3cede5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1['EDAD_ASEGURADO'] = dfp1['EDAD_ASEGURADO'].astype(str).copy()
# <ipython-input-112-f7adde3cede5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs1['EDAD_ASEGURADO'] = dfs1['EDAD_ASEGURADO'].astype(str).copy()
#                       KEY    SSEGURO EDAD_ASEGURADO_p EDAD_ASEGURADO_s
# 2      6014329-19-LIBERTY     789926               70               71
# ...
